# %% [markdown]
# # Amazon Textract - Receipts Demo
#
# In the following notebook, we will examine the use of Amazon Textract in order to perform optical character recognition (OCR), and then use Amazon Machine Learning to organize the dataset.
#
#
# **Contents:**
# - Part 0 - Housekeeping
# - Part 1 - Data Download and Amazon TExtract Enrichment
# - Part 2 - Data Enrichment (NLTK/SPACY) and Exploration
#     - 2.1 POS and NER
#     - 2.2 Data Analysis
#     - 2.3 Term Co-occerence
#     - 2.4 Word Embeddings

# %% [markdown]
# ## Part 0. Housekeeping

# %% [markdown]
# ### General Imports
#
# These are the libraries which we will require in order to complete different types of operations.
#
# Just a quick note, you may need to use ```nltk.download()``` in order to download the correct libraries and additional packages required to perform text tagging

# %%
import boto3
import sagemaker
import sys
import os
import re
import numpy as np
import pandas as pd
import subprocess
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
import gzip
from io import BytesIO
import zipfile
import random
import json
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.metrics import classification_report
from sklearn.preprocessing import normalize
from sklearn.manifold import TSNE
from matplotlib import pylab
import nltk 
import spacy
import en_core_web_lg
from datetime import datetime
from wordcloud import WordCloud, STOPWORDS
from nltk.stem import PorterStemmer 
import string
import pickle
from nltk.corpus import stopwords 
from itertools import combinations 
import operator
from io import BytesIO
import tarfile

# %% [markdown]
# ### Constant Set-up
# Configure all global constants here, these are variables which will remain constant throughout the execution of the notebook.

# %%
configs = {
    'aws_region' :  'us-east-1',
    'bucket_name': 'aws-demo-receipts',
    'prefix' : 'preprocessed_reviews', #only use this if you want to have your files in a folder 
    'dataset_path_s3' : 'receipts_data/',
    'training_data_prefix_s3' : 'training_data/',
    'output_data_s3' : 'output_data/',
    'dataset_zipped_filename': 'large-receipt-image-dataset-SRD.zip',
    'dataset_zipped_path':'data_zipped/',
    'tmp_folder':'tmp/',
    'stopwords_custom': 'stopwords_custom.txt'
   
}

global_vars = {}

# %% [markdown]
# ### Environment Setup
#
# Setting up the environment involves ensuring all the corret session and IAM roles are configured. We also need to ensure the correct region and bucket is made available.

# %%
def setup_env(configs, global_vars):
   
    sess = sagemaker.Session()
    
    role = get_execution_role()

    AWS_REGION = configs['aws_region']
    s3 = boto3.resource('s3')

    s3_bucket = s3.Bucket(configs['bucket_name'])

    if s3_bucket.creation_date == None:
    # create S3 bucket because it does not exist yet
        print('Creating S3 bucket {}.'.format(bucket))
        resp = s3.create_bucket(
            ACL='private',
            Bucket=bucket
        )
    else:
        print('Bucket already exists')
        
    global_vars['role'] = role
    global_vars['sess'] = sess
    global_vars['s3'] = s3
    global_vars['s3_bucket'] = s3_bucket
    
    
    #set up textract
    textract = boto3.client('textract')
    
    global_vars['textract'] = textract

    
    return global_vars

global_vars = setup_env(configs, global_vars)
# Out:
# Bucket already exists

# %%
def setup_nlp(configs, global_vars):
    
    nlp = en_core_web_lg.load()
    global_vars['nlp'] = nlp
    stop_words = []
    with open(configs['stopwords_custom'], 'r') as file:
        for line in file:
            stop_words.append(line.strip())
    global_vars['stop_words'] = stop_words
    return global_vars

global_vars = setup_nlp(configs, global_vars)

# %% [markdown]
# ## Part 1. Download Data and Perform OCR using Amazon TExtract
#
# Here we are goin to download the data to our bucket if it does not already exist. This dataset is a pre-compiled dataset of car images which contain 2 typers:
#
# - Whole (e.g. without damage)
# - Damaged (e.g. those with damage)
#
# The following create_dataset method will first download the Zip of the data, and then unpack it to the bucket named in the global constants

# %%
def create_dataset(configs, global_vars):
    
    dataset_key = configs['dataset_path_s3']
    s3_bucket = global_vars['s3_bucket']
    objs = list(s3_bucket.objects.filter(Prefix=dataset_key))

    if len(objs) > 0 and objs[0].key == configs['dataset_zipped_filename']:
        exists = True
        print('{} Already Exists, No need to copy to S3 or Unzip'.format(dataset_key) )
    else:
        exists = False
    
    if not exists:
        
        data_path = configs['dataset_zipped_path'] + configs['dataset_zipped_filename']
        data_file_s3 = configs['dataset_path_s3'] + configs['dataset_zipped_filename']
        s3_bucket.upload_file(data_path, data_file_s3)

        s3 = boto3.client('s3', use_ssl=False)
        Key_unzip = configs['dataset_path_s3']

    
        s3_resource = boto3.resource('s3')
        #Now create zip object one by one, this below is for 1st file in file_list
        zip_obj = s3_resource.Object(bucket_name=bucket_name, key=data_file_s3)
        
        print('Unpacking {}\n'.format(data_file_s3))
        print (zip_obj)
        buffer = BytesIO(zip_obj.get()["Body"].read())
        z = zipfile.ZipFile(buffer)
        for filename in z.namelist():
            file_info = z.getinfo(filename)
            s3_resource.meta.client.upload_fileobj(
                z.open(filename),
                Bucket=bucket_name,
                Key=Key_unzip + f'{filename}')
            
        
    
# create_dataset(bucket_name, s3_bucket)

# %%
def test_textract(configs, global_vars, show_image = False):
    
    #first download a temp document
    tmp_folder = configs['tmp_folder']
    try:
        os.mkdir(tmp_folder)
    except:
        pass
    
    s3_bucket = global_vars['s3_bucket']
    s3 = global_vars['s3']
    
    s3_path = configs['dataset_path_s3']
    objs = list(s3_bucket.objects.filter(Prefix=s3_path))
    
    files_data = {}
    for entry in objs:
        print(entry.key)
        file_data = []
        if 'jpg' in entry.key:
            local_path = tmp_folder + 'tmp.jpg'
            s3.Bucket(configs['bucket_name']).download_file(str(entry.key), local_path)  
            
            with open(local_path, 'rb') as document:
                imageBytes = bytearray(document.read())
            
            response = global_vars['textract'].detect_document_text(Document={'Bytes': imageBytes})

            if show_image:
                raw_img = mpimg.imread(local_path)
                height, width, depth = raw_img.shape
                dpi = 80
                figsize = width / float(dpi), height / float(dpi)
                plt.figure(figsize = figsize)
                plt.imshow(raw_img, aspect='auto')

            files_data[entry.key] =  response
            
    return files_data


    
    
textract_data = test_textract(configs, global_vars)
# Out:
# receipts_data/
# receipts_data/1000-receipt.jpg
# receipts_data/1001-receipt.jpg
# receipts_data/1002-receipt.jpg
# receipts_data/1003-receipt.jpg
# receipts_data/1004-receipt.jpg
# receipts_data/1005-receipt.jpg
# receipts_data/1006-receipt.jpg
# receipts_data/1007-receipt.jpg
# receipts_data/1008-receipt.jpg
# receipts_data/1009-receipt.jpg
# receipts_data/1010-receipt.jpg
# receipts_data/1011-receipt.jpg
# receipts_data/1012-receipt.jpg
# receipts_data/1013-receipt.jpg
# receipts_data/1014-receipt.jpg
# receipts_data/1015-receipt.jpg
# receipts_data/1016-receipt.jpg
# receipts_data/1017-receipt.jpg
# receipts_data/1018-receipt.jpg
# receipts_data/1019-receipt.jpg
# receipts_data/1020-receipt.jpg
# receipts_data/1021-receipt.jpg
# receipts_data/1022-receipt.jpg
# receipts_data/1023-receipt.jpg
# receipts_data/1024-receipt.jpg
# receipts_data/1025-receipt.jpg
# receipts_data/1026-receipt.jpg
# receipts_data/1027-receipt.jpg
# receipts_data/1028-receipt.jpg
# receipts_data/1029-receipt.jpg
# receipts_data/1030-receipt.jpg
# receipts_data/1031-receipt.jpg
# receipts_data/1032-receipt.jpg
# receipts_data/1033-receipt.jpg
# receipts_data/1034-receipt.jpg
# receipts_data/1035-receipt.jpg
# receipts_data/1036-receipt.jpg
# receipts_data/1037-receipt.jpg
# receipts_data/1038-receipt.jpg
# receipts_data/1039-receipt.jpg
# receipts_data/1040-receipt.jpg
# receipts_data/1041-receipt.jpg
# receipts_data/1042-receipt.jpg
# receipts_data/1043-receipt.jpg
# receipts_data/1044-receipt.jpg
# receipts_data/1045-receipt.jpg
# receipts_data/1046-receipt.jpg
# receipts_data/1047-receipt.jpg
# receipts_data/1048-receipt.jpg
# receipts_data/1049-receipt.jpg
# receipts_data/1050-receipt.jpg
# receipts_data/1051-receipt.jpg
# receipts_data/1052-receipt.jpg
# receipts_data/1053-receipt.jpg
# receipts_data/1054-receipt.jpg
# receipts_data/1055-receipt.jpg
# receipts_data/1056-receipt.jpg
# receipts_data/1057-receipt.jpg
# receipts_data/1058-receipt.jpg
# receipts_data/1059-receipt.jpg
# receipts_data/1060-receipt.jpg
# receipts_data/1061-receipt.jpg
# receipts_data/1062-receipt.jpg
# receipts_data/1063-receipt.jpg
# receipts_data/1064-receipt.jpg
# receipts_data/1065-receipt.jpg
# receipts_data/1066-receipt.jpg
# receipts_data/1067-receipt.jpg
# receipts_data/1068-receipt.jpg
# receipts_data/1069-receipt.jpg
# receipts_data/1070-receipt.jpg
# receipts_data/1071-receipt.jpg
# receipts_data/1072-receipt.jpg
# receipts_data/1073-receipt.jpg
# receipts_data/1074-receipt.jpg
# receipts_data/1075-receipt.jpg
# receipts_data/1076-receipt.jpg
# receipts_data/1077-receipt.jpg
# receipts_data/1078-receipt.jpg
# receipts_data/1079-receipt.jpg
# receipts_data/1080-receipt.jpg
# receipts_data/1081-receipt.jpg
# receipts_data/1082-receipt.jpg
# receipts_data/1083-receipt.jpg
# receipts_data/1084-receipt.jpg
# receipts_data/1085-receipt.jpg
# receipts_data/1086-receipt.jpg
# receipts_data/1087-receipt.jpg
# receipts_data/1088-receipt.jpg
# receipts_data/1089-receipt.jpg
# receipts_data/1090-receipt.jpg
# receipts_data/1091-receipt.jpg
# receipts_data/1092-receipt.jpg
# receipts_data/1093-receipt.jpg
# receipts_data/1094-receipt.jpg
# receipts_data/1095-receipt.jpg
# receipts_data/1096-receipt.jpg
# receipts_data/1097-receipt.jpg
# receipts_data/1098-receipt.jpg
# receipts_data/1099-receipt.jpg
# receipts_data/1100-receipt.jpg
# receipts_data/1101-receipt.jpg
# receipts_data/1102-receipt.jpg
# receipts_data/1103-receipt.jpg
# receipts_data/1104-receipt.jpg
# receipts_data/1105-receipt.jpg
# receipts_data/1106-receipt.jpg
# receipts_data/1107-receipt.jpg
# receipts_data/1108-receipt.jpg
# receipts_data/1109-receipt.jpg
# receipts_data/1110-receipt.jpg
# receipts_data/1111-receipt.jpg
# receipts_data/1112-receipt.jpg
# receipts_data/1113-receipt.jpg
# receipts_data/1114-receipt.jpg
# receipts_data/1115-receipt.jpg
# receipts_data/1116-receipt.jpg
# receipts_data/1117-receipt.jpg
# receipts_data/1118-receipt.jpg
# receipts_data/1119-receipt.jpg
# receipts_data/1120-receipt.jpg
# receipts_data/1121-receipt.jpg
# receipts_data/1122-receipt.jpg
# receipts_data/1123-receipt.jpg
# receipts_data/1124-receipt.jpg
# receipts_data/1125-receipt.jpg
# receipts_data/1126-receipt.jpg
# receipts_data/1127-receipt.jpg
# receipts_data/1128-receipt.jpg
# receipts_data/1129-receipt.jpg
# receipts_data/1130-receipt.jpg
# receipts_data/1131-receipt.jpg
# receipts_data/1132-receipt.jpg
# receipts_data/1133-receipt.jpg
# receipts_data/1134-receipt.jpg
# receipts_data/1135-receipt.jpg
# receipts_data/1136-receipt.jpg
# receipts_data/1137-receipt.jpg
# receipts_data/1138-receipt.jpg
# receipts_data/1139-receipt.jpg
# receipts_data/1140-receipt.jpg
# receipts_data/1141-receipt.jpg
# receipts_data/1142-receipt.jpg
# receipts_data/1143-receipt.jpg
# receipts_data/1144-receipt.jpg
# receipts_data/1145-receipt.jpg
# receipts_data/1146-receipt.jpg
# receipts_data/1147-receipt.jpg
# receipts_data/1148-receipt.jpg
# receipts_data/1149-receipt.jpg
# receipts_data/1150-receipt.jpg
# receipts_data/1151-receipt.jpg
# receipts_data/1152-receipt.jpg
# receipts_data/1153-receipt.jpg
# receipts_data/1154-receipt.jpg
# receipts_data/1155-receipt.jpg
# receipts_data/1156-receipt.jpg
# receipts_data/1157-receipt.jpg
# receipts_data/1158-receipt.jpg
# receipts_data/1159-receipt.jpg
# receipts_data/1160-receipt.jpg
# receipts_data/1161-receipt.jpg
# receipts_data/1162-receipt.jpg
# receipts_data/1163-receipt.jpg
# receipts_data/1164-receipt.jpg
# receipts_data/1165-receipt.jpg
# receipts_data/1166-receipt.jpg
# receipts_data/1167-receipt.jpg
# receipts_data/1168-receipt.jpg
# receipts_data/1169-receipt.jpg
# receipts_data/1170-receipt.jpg
# receipts_data/1171-receipt.jpg
# receipts_data/1172-receipt.jpg
# receipts_data/1173-receipt.jpg
# receipts_data/1174-receipt.jpg
# receipts_data/1175-receipt.jpg
# receipts_data/1176-receipt.jpg
# receipts_data/1177-receipt.jpg
# receipts_data/1178-receipt.jpg
# receipts_data/1179-receipt.jpg
# receipts_data/1180-receipt.jpg
# receipts_data/1181-receipt.jpg
# receipts_data/1182-receipt.jpg
# receipts_data/1183-receipt.jpg
# receipts_data/1184-receipt.jpg
# receipts_data/1185-receipt.jpg
# receipts_data/1186-receipt.jpg
# receipts_data/1187-receipt.jpg
# receipts_data/1188-receipt.jpg
# receipts_data/1189-receipt.jpg
# receipts_data/1190-receipt.jpg
# receipts_data/1191-receipt.jpg
# receipts_data/1192-receipt.jpg
# receipts_data/1193-receipt.jpg
# receipts_data/1194-receipt.jpg
# receipts_data/1195-receipt.jpg
# receipts_data/1196-receipt.jpg
# receipts_data/1197-receipt.jpg
# receipts_data/1198-receipt.jpg
# receipts_data/1199-receipt.jpg

# %% [markdown]
# ### Useful Method if you want to resume a session if the kernal dies

# %%
def load_or_save_record_meta_data(textract_data=None, load_or_save='load'):
    
    tmp_filename = 'tmp.pickle'
    if load_or_save == 'load':
        with open(tmp_filename, 'rb') as handle:
            data = pickle.load(handle)
        return data

        
    if load_or_save == 'save':
        with open(tmp_filename, 'wb') as handle:
            pickle.dump(textract_data, handle, protocol=pickle.HIGHEST_PROTOCOL)  
        print('Saved to {}'.format(tmp_filename))
        return textract_data
    
textract_data = load_or_save_record_meta_data('', 'load')

# %% [markdown]
# ## Part 2. Dataset Enrichment and Exploration
#
# In this section, we're going to be exploring different analytical approaches to interpretting the receipt data. This is an important part of any data science driven experiment, as the exploration (and through the iterations of exploration), will help us derive the most useful insights for a given use case.

# %%
def inspect_dataset(textract_data):
    
    print('Total Records {}'.format(len(textract_data)))

inspect_dataset(textract_data)
# Out:
# Total Records 200

# %% [markdown]
# ### 2.1 Process Data
#
# Using Textract's repsponse, we look at each word in our data, and store it with it's confidence scores. Then a series of data enrichment processes take place.
#
# Note, we use a filtering approach to ensure that we are not introducing random stop words..
#
# #### Enriching the Textract Results
#
# The Following methods will be used to enrich each of the records with additional information.
#
# We're going to use two libraries to perform our enrichment, ```NLTK```, and ```Spacy```.
#
# #### Part of Speech Tagging (POS)
#
# In the world of Natural Language Processing (NLP), the most basic models are based on Bag of Words. But such models fail to capture the syntactic relations between words. ... POS tagging is the process of marking up a word in a corpus to a corresponding part of a speech tag, based on its context and definition.
#
# For Part of Speak Tagging, we're using NLTK. More details can be found here:
#
# https://www.nltk.org/api/nltk.tag.html
#
# The tags which NLTK uses are as follows:
#
#  - CD - cardinal numbers
#  - AT -Articles
#  - JJ - Adjectives
#  - NN Nouns
#  - NNS - Plural Nouns
#  - RB - adverbs
#  - VGB - gerunds
#  - VBD - past tense verbs
#
# #### Named Entity Recognition (NER)
#
# Named-entity recognition (NER) (also known as entity identification, entity chunking and entity extraction) is a subtask of information extraction that seeks to locate and classify named entity mentioned in unstructured text into pre-defined categories such as person names, organizations, locations, medical codes, time expressions, quantities, monetary values, percentages, etc.
#
# For our NER, spaCy features an extremely fast statistical entity recognition system, that assigns labels to contiguous spans of tokens. The default model identifies a variety of named and numeric entities, including companies, locations, organizations and products.
#
# For More information on Spacey, please take a read here:
#
#
#
# The Tags which Space use are as follows:
#
#  - PERSON	People, including fictional.
#  - NORP	Nationalities or religious or political groups.
#  - FAC	Buildings, airports, highways, bridges, etc.
#  - ORG	Companies, agencies, institutions, etc.
#  - GPE	Countries, cities, states.
#  - LOC	Non-GPE locations, mountain ranges, bodies of water.
#  - PRODUCT	Objects, vehicles, foods, etc. (Not services.)
#  - EVENT	Named hurricanes, battles, wars, sports events, etc.
#  - WORK_OF_ART	Titles of books, songs, etc.
#  - LAW	Named documents made into laws.
#  - LANGUAGE	Any named language.
#  - DATE	Absolute or relative dates or periods.
#  - TIME	Times smaller than a day.
#  - PERCENT	Percentage, including ”%“.
#  - MONEY	Monetary values, including unit.
#  - UANTITY	Measurements, as of weight or distance.
#  - ORDINAL	“first”, “second”, etc.
#  - CARDINAL	Numerals that do not fall under another type.

# %%
def process_textract_text(data, print_output= True):
    
    currencies = ['$',' £','€']
    
    values = []
    currency_values = []
    
    words = []
    
    UPPER_BOUND = 2000.0
    
    for line in data:
        #first see if it can be recognised as a value:
        if any(ext in line for ext in currencies):
            currency_values.append(line)
#             print(line)
        else:
            try:
                value = float(line)
                values.append(value)
            except:
                pass
            
        #now P O W taggig
        wrds = nltk.word_tokenize(line)
        words = words + wrds
    
    #nltk POS tagging
    nltk_tagged_words = nltk.pos_tag(words)
    
    #perform Spacy Analysis:
    spacey_enriched_words = spacey_enricher(global_vars, data)
    
    verbs = []
    nouns = []
    cds = []
    products = []
    locations = []
    organisations = []
    dates = []
    for entry in nltk_tagged_words:
#         print(entry)
        k = entry[0]

        v = entry[1]
        if v == 'NN' or v == 'NNS':
            nouns.append(k)
            
        if v == 'VBD' or v == 'VGB':
            verbs.append(k)
        
        if v == 'CD':
            cds.append(k)  
            
           
    #process SPACEY results
    for entry in spacey_enriched_words.ents:
        if entry.label_ is 'PRODUCT':
            products.append(entry.text)
        
        if entry.label_ is 'LOC':
            locations.append(entry.text)
        
        if entry.label_ is 'ORG':
            organisations.append(entry.text)
            
#         if entry.label_ is 'DATE':
#             dates.append(entry.text)
                    
    #calculate max cardinal values
    cds_float = []
    for value in cds:
        #firsr monetary values
        try:
            if ('.' in value):
                tmp = float(value)
                if tmp < UPPER_BOUND:
                    cds_float.append(tmp) 
        except:
            pass
       
        #now dates
        try:
            date_tmp = pd.to_datetime(str(value))
            #avoid the case where the hh:mm:ss is only found, and then pandas creates a date which is current day
            if date_tmp.date() != datetime.today().date():
                dates.append(str(date_tmp))
        except Exception as e:
            pass
            
    record_data = {}
    record_data['verbs'] = verbs
    record_data['nouns'] = nouns
    record_data['cardinals'] = cds
    record_data['products'] = products
    record_data['companies'] = organisations
    record_data['locations'] = locations
    record_data['dates'] = dates
    record_data['currency_values'] = dates
    record_data['values_raw'] = values
    record_data['tokens'] = words
    


    if len(cds_float) > 0:
        record_data['max_value'] = max(cds_float)
    else:
        record_data['max_value'] = 0


    
    if print_output:
         
        print('Currency Linked Value: {}'.format(currency_values))
        print('Raw Values: {}'.format(values))
    #     print('Tagged Words: {}'.format(nltk_tagged_words))
        print('Verbs: {}'.format(verbs))
        print('Nouns: {}'.format(nouns))
        print('Cardinal Values: {}'.format(cds))
        print('Products {}'.format(products))
        print('Companies {}'.format(organisations))
        print('Locations {}'.format(locations))
        print('Dates {}'.format(dates))
        print('MAX Value {}'.format( record_data['max_value']))
        print('\n ### \n')

    return record_data

# %%
def spacey_enricher(global_vars, words_list):
    string_of_words = ' '.join(map(str, words_list)) 
    
    string_of_words = string_of_words
#     print(string_of_words)
    doc = global_vars['nlp'](string_of_words)
    #returned with a list of entities (ents), which have k,v of (text, label_)
#     print([(X.text, X.label_) for X in doc.ents])
    return doc

# %%
def process_textract_responses(global_vars, data):
    stop_words = global_vars['stop_words']
    stop_words_nltk = stopwords.words('english')
    ps = PorterStemmer()
    exclude = set(string.punctuation)
    table = str.maketrans('', '', string.punctuation)

    records_enriched = {}
    removed_tokens = 0
    for key,response in data.items():
        line_data = []
        confidences = []
        for item in response["Blocks"]:
                if item["BlockType"] == "WORD":
                    
                    #we need to normailise and remove punctuation.
                    word = item["Text"].lower().strip().replace(',','').replace(':',''). \
                    replace('?','').replace('000','').replace('>','').replace('<','').replace('!',''). \
                    replace(')','').replace('(','').replace('#','')
                   
                    #now remove all punctuation
#                     if not word.isdigit():
#                     word = word.translate(table)
                    #we have some oddities
                    word =  ' '.join(i for i in word.split(' ') if not i.endswith('pm'))
                    word  = ' '.join(i for i in word.split(' ') if not i.endswith('am'))
            
                    word_stemmed = ps.stem(word)
                
                    if (word_stemmed not in stop_words) and (word not in stop_words) and (word_stemmed not in stop_words_nltk):
                        #first stem the word
                        
                        #final some last checks
                        if (word_stemmed.isspace() == False) and (len(str(word_stemmed)) > 2):
                        
                            line_data.append(word_stemmed)
                            confidences.append({'word':word_stemmed,'confidence':item['Confidence']})
                    else:
                        removed_tokens += 1
                    
        #now we have the data
        record_data = process_textract_text(line_data, True)
        record_data['word_confidences'] = confidences
        records_enriched[key] = record_data
    
    print('Text Enrichment Finished. {} Records processed, {} Tokens removed'.format(len(records_enriched), removed_tokens)) 
    return records_enriched
    
records_enriched = process_textract_responses(global_vars, textract_data)
# Out:
# Currency Linked Value: ['$56.58']
# Raw Values: [5305.0, 90804.0, 562.0, 69923.0, 3.0, 45.9, 3.0, 51.9, 4.68, 125310.0]
# Verbs: ['coke']
# Nouns: ['field', 'pacif', 'coast', 'hwi', 'beach', 'franci', 'b11', 'coffe', 'lunch']
# Cardinal Values: ['5305', '90804', '562', '69923', '3.00', '45.90', '3.00', '51.90', '4.68', '56.58', '5/26/2016', '125310']
# Products ['597-0906']
# Companies ['green field 5305', 'pacif coast', 'coffe']
# Locations []
# Dates ['2016-05-26 00:00:00']
# MAX Value 56.58
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [480.0, 101.0, 1643.0, 2.95, 17.95, 25.95, 13.95, 2.95, 63.75, 5.5, 69.25, 1742.0, 69.25, 13.85, 12.47, 10.39]
# Verbs: ['roosevelt']
# Nouns: ['luxcaf', 'field', 'parti', 'stephen', 'svrck', 'coffe', 'chicken', 'parmesan', 'sirloin', 'burger', 'coffe', '%', '%', '%', 'pleasur']
# Cardinal Values: ['0480', '101', '1643', '04/25/15', '2.95', '17.95', '25.95', '13.95', '2.95', '63.75', '5.50', '69.25', '04/25', '1742', '69.25', '20', '13.85', '18', '12.47', '15', '10.39']
# Products []
# Companies ['coffe']
# Locations []
# Dates ['2015-04-25 00:00:00', '1742-01-01 00:00:00']
# MAX Value 69.25
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [17314.0, 7230.0, 31755411846.226, 378752.0, 83538.0, 4.99, 0.0, 0.0, 1.99, 6.98, 0.63, 7.61, 7.61, 571883.0]
# Verbs: ['bow']
# Nouns: ['digano', 'code', 'win', 'chanc', 'bel', 'pendleton', 'daja', 'power', 'veg', 'chees', 'crsh', 'acct', 'drive', 'thru', 'taco', 'mobil', 'download', 'app']
# Cardinal Values: ['4', '017314', '7230', '31755411846.226', '9/1/2016', '378752', '83538', '4.99', '0.00', '0.00', '1.99', '6.98', '0.63', '7.61', '7.61', '571883']
# Products ['chanc espanol laco bel 017314', 'veg bow']
# Companies ['awrenc pendleton', 'daja 83538', 'chees', 'taco mobil', 'wer download th']
# Locations []
# Dates ['2016-09-01 00:00:00']
# MAX Value 7.61
#
#  ###
#
# Currency Linked Value: ['$5.35', '$0.00']
# Raw Values: [10325.0, 33176.0, 305.0, 8262.0, 5.0, 5.0, 0.35, 5.35, 101317.0, 101325.0]
# Verbs: ['plata']
# Nouns: ['gran', 'mar', 'miami', 'hammock', 'kayra', 'tab', 'tab', 'miller', 'lite', 'tender', 'creat', 'settl', 'way', 'ialay', 'sot', 'chovg', 'dob', 'exb', 'iue']
# Cardinal Values: ['10325', '33176', '305', '8262', '5.00', '5.00', '0.35', '5.35', '5.35', '0.00', '4/20/2017', '101317', '4/20/2017', '101325']
# Products ['386-6638']
# Companies ['gran mar plata 10325', 'iue']
# Locations []
# Dates ['2017-04-20 00:00:00', '2017-10-13 00:00:00', '2017-04-20 00:00:00', '2025-10-13 00:00:00']
# MAX Value 5.35
#
#  ###
#
# Currency Linked Value: ['$9.39', '$1.95', '$2.29', '$1.40', '$15', '$20.00', '$4.97']
# Raw Values: [8610.0, 90280.0, 562.0, 1119.0, 141.0, 141.0]
# Verbs: []
# Nouns: ['bowl', 'teriyaki', 'garfield', 'ave', 'gate', 'reg', 'manag', 'coo', 'chkn', 'plate', 'md', 'total']
# Cardinal Values: ['8610', '90280', '562', '1119', '141', '141', '9.39', '1.95', '2.29', '1.40', '15', '20.00', '4.97']
# Products ['562', '928-8999']
# Companies ['golden bowl', 'manag 141']
# Locations []
# Dates []
# MAX Value 20.0
#
#  ###
#
# Currency Linked Value: ['=$30.06', '=$33.40', '=$36.74']
# Raw Values: [3768.0, 92109.0, 858.0, 551.0, 7.0, 45.0, 5.0, 21.0, 5.0, 10.0, 20.0, 40.0, 1602.0, 34.0, 5.0, 167.0, 12.94, 179.94, 179.94]
# Verbs: ['san', 'rye']
# Nouns: ['saska', 'mission', 'sue', 'draft', 'cowboy', 'ribey', 'make', 'lobster', 'manhattan', 'whistl', 'pig', 'duke', 'sirloin', 'make', 'blue', '%', '%', '%']
# Cardinal Values: ['3768', '92109', '858', '08/15/2017', '103/1', '551', '7.00', '160z', '45.00', '5.00', '21.00', '05.00', '10.00', '10yr', '020.00', '40.00', '2bmod', '1602', '34.00', '5.00', '167.00', '12.94', '179.94', '179.94', '18', '30.06', '20', '33.40', '22', '36.74']
# Products []
# Companies ['saska', 'ribey']
# Locations []
# Dates ['2017-08-15 00:00:00']
# MAX Value 179.94
#
#  ###
#
# Currency Linked Value: ['$22.95', '$200', '$20.75', '$15.95', '$6.50', '$13.00', '$5.50', '$86.05', '$6. 03', '$93.58']
# Raw Values: [386.0, 12077.0]
# Verbs: ['steakk', 'deluxx', 'rol']
# Nouns: ['pickup', 'leo', 'phil', 'oti', 'amt', 'hi.chk', 'sushi', 'glenmont']
# Cardinal Values: ['386', '12077', '185834', '22.95', '200', '20.75', '15.95', '6.50', '13.00', '5.50', '86.05', '6', '03', '93.58']
# Products []
# Companies ['philli']
# Locations []
# Dates []
# MAX Value 93.58
#
#  ###
#
# Currency Linked Value: ['$12.00', '$17.00', '$12.00', '$11.00', '$10.00', '$36.00', '$12.00', '$10.00', '$11.00', '$131.00', '$12.71', '$143.71']
# Raw Values: [2818.0, 98201.0, 847.0, 1577.0]
# Verbs: ['everett', 'poke', 'sashimi', 'sashimi', 'sashimi', 'sashimi', 'japapeno', 'sashimi']
# Nouns: ['katana', 'sushi', 'hewitt', 'micha', 'hamachi', 'hamachi', 'maguro', 'salmon', 'salmon', 'hamachi', 'salmon', 'visit']
# Cardinal Values: ['2818', '98201', '05/11/18', '847', '12.00', '17.00', '12.00', '11.00', '10.00', '36.00', '12.00', '10.00', '11.00', '131.00', '12.71', '143.71', '1577']
# Products ['-512-9361', 'micha']
# Companies ['katana sushi', 'hamachi', 'sockey']
# Locations []
# Dates ['2018-05-11 00:00:00']
# MAX Value 143.71
#
#  ###
#
# Currency Linked Value: ['$2.25', '$6.75', '$7.75', '$1.50', '$4.00', '$22.25', '$2.22', '$24.47', '$4.40', '$4.89', '$6.12']
# Raw Values: [1030.0, 91341.0]
# Verbs: ['merced', 'fernando', 'chicharon', 'queso', 'coke', 'salvadorena']
# Nouns: ['dona', 'san', 'vero', 'center', 'pupusa', 'platano', 'quesadilla', '%', '%', '%']
# Cardinal Values: ['1030', '1/2', '91341', '2.25', '6.75', '7.75', '1.50', '4.00', '22.25', '2.22', '24.47', '18', '4.40', '20', '4.89', '25', '6.12']
# Products []
# Companies ['vero', 'chicharon']
# Locations []
# Dates []
# MAX Value 24.47
#
#  ###
#
# Currency Linked Value: ['$12.99', '$12.99', '$2.50', '$28.48', '$2.28', '$30.76']
# Raw Values: [286.0, 223.0, 401.0]
# Verbs: ['aye', 'gorgonzola']
# Nouns: ['pasta', 'bella', 'pasta', 'pautucket', 'neuport', 'wuu', 'google/fagebook/yeyp/trip', 'advisor', 'steak', 'piatto', 'root', 'beer', 'grub', 'hub', 'eat', 'hour', 'cuandou']
# Cardinal Values: ['0286', '223', '401', '08/09/19', '428', '12.99', '12.99', '2.50', '28.48', '2.28', '30.76', '2', '0..']
# Products ['722-6297']
# Companies []
# Locations []
# Dates ['2019-08-09 00:00:00']
# MAX Value 30.76
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [1256.0, 10076.0, 28.0, 14.0, 12.0, 10.0, 7.4, 71.4, 6.43, 77.83, 77.8]
# Verbs: ['margarita', 'light']
# Nouns: ['giancarlo', 'cadillac', 'patron', 'silver', 'maryland', 'crab', 'chicken', 'capres', 'parm', 'sandwich', 'bud', 'join']
# Cardinal Values: ['07/21/2018', '104/1', '1256', '10076', '2', '14.00', '28.00', '14.00', '12.00', '10.00', '2', '3', '70', '7.40', '71.40', '6.43', '77.83', '77.8']
# Products ['margarita 2', '7.40']
# Companies ["friendli red'", 'cadillac', 'chix parm']
# Locations []
# Dates ['2018-07-21 00:00:00']
# MAX Value 77.83
#
#  ###
#
# Currency Linked Value: ['$36.86', '$19.60/b', '$8.50', '$0.00', '$3.35', '$4.20', '$3.95', '$2.25', '$59.11', '$5.32', '$64.43', '$64.43', '$0.00']
# Raw Values: [5242.0, 91401.0, 455.0, 234673.0, 1.89]
# Verbs: [']', 'soda']
# Nouns: ['market', 'smoke', 'van', 'oak', 'rebecca', 'rebecca', 'jun', 'beef', 'rib', 'weight', 'pull', 'pork', 'cream', 'corn', 'longhorn', 'mac', 'sm', 'chocol', 'cake', 'slice', 'fountain', 'websit', 'www.smokecitymarket.com', 'bbq', 'yelp', 'rate', 'zagat', 'zagat', 'com/rismoke-city-market-van-nu']
# Cardinal Values: ['5242', '91401', '818.855.1280', '0455', '234673', '36.86', '1.89', '19.60/b', '8.50', '0.00', '3.35', '4.20', '3.95', '2.25', '59.11', '5.32', '64.43', '64.43', '0.00']
# Products ['longhorn mac cheese[sm']
# Companies ['websit']
# Locations []
# Dates []
# MAX Value 64.43
#
#  ###
#
# Currency Linked Value: ['$33.26', '$33']
# Raw Values: [8930.0, 102.0, 91770.0, 2019.0, 59980.0, 8.0, 9.0, 5.25, 22.25, 2.11, 24.36, 8.9, 3.65, 4.38, 4.87, 2019.0]
# Verbs: []
# Nouns: ['pho', 'mission', 'dr', 'apr', 'admin', 'bill', 'pho', 'pho', 'larg', 'goi', 'cuon', '%', '%', '%', '%', 'apr', 'admin']
# Cardinal Values: ['8930', '102', '91770', '2019', '59980', '8.00', '9.00', '5.25', '22.25', '2.11', '24.36', '40', '8.90', '33.26', '33', '15', '3.65', '18', '4.38', '20', '4.87', '2019']
# Products []
# Companies ['pho']
# Locations []
# Dates ['2019-01-01 00:00:00', '2019-01-01 00:00:00']
# MAX Value 33.26
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [11732.0, 562.0, 1029.0, 8.1, 0.75, 8.85, 0.73, 9.58, 9.58, 636.0]
# Verbs: []
# Nouns: ['albeto', 'artesia', 'blvd', 'artesiaca', 'welcom', 'asada', 'taco', 'atm', 'atm']
# Cardinal Values: ['11732', '562', '01029', '8.10', '0.75', '8.85', '0.73', '9.58', '9.58', '636']
# Products []
# Companies []
# Locations []
# Dates []
# MAX Value 9.58
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [15700.0, 90706.0, 135.0, 2763.0, 25.98, 319.0, 3.19, 2.99, 2.99, 2.99, 2.99, 44.32, 4.21, 48.53]
# Verbs: ['enchi', 'shred', 'coke']
# Nouns: ['load', 'bellflow', 'tbl', "feb23'19", 'beef', 'beeg', 'side', 'side', 'coffe']
# Cardinal Values: ['15700', '90706', '135', '34/1', '2763', '25.98', '319', '3.19', '2.99', '2.99', '2.99', '2.99', '44.32', '4.21', '48.53']
# Products ['hashbrown', '4.21']
# Companies ['enchi', 'hashbrown', 'coke']
# Locations []
# Dates ['2034-01-01 00:00:00']
# MAX Value 48.53
#
#  ###
# Currency Linked Value: []
# Raw Values: [7285.0, 30328.0, 623.0, 2.5, 21.0, 6.0, -6.0, 2.5, 21.0, 47.0, 3.29, 50.29, 50.29]
# Verbs: ['www', 'shannon', 'coke', 'entre']
# Nouns: ['hammock', 'trade', 'compani', 'roswel', 'sandi', 'spring', 'georgia', 'nicetomeat', 'tbl40', 'ref', 'f15509', 'chk202524', 'shrimp', 'mac', 'chees', 'chz', 'chip', 'bbq', 'chz', 'lobster', 'roll', 'state', 'oyster', 'half', 'daili']
# Cardinal Values: ['7285', '30328', '3/10/2017', '623', '2.50', '21.00', '6.00', '2.50', '21.00', '47.00', '3.29', '50.29', '50.29', '1/2']
# Products ['chees french', 'blue chz -6.00']
# Companies ['w.hammockstradingcompany.con', 'mac']
# Locations []
# Dates ['2017-03-10 00:00:00']
# MAX Value 50.29
#
#  ###
#
# Currency Linked Value: ['$5.25', '$9.95', '$8.75', '$8.75', '$32.70', '$2.82', '$35.52']
# Raw Values: [1902.0, 11040.0, 1022.0, 214.0, 303.0]
# Verbs: ['turnpik', 'pancak', 'bun', 'choy', 'beef']
# Nouns: ['chef', 'wang', 'lericho', 'hyde', 'park', 'fax', 'lili', 'person', 'scallion', 'littl', 'juici', 'pork', 'beef', 'bak', 'hunan', 'day']
# Cardinal Values: ['1902', '11040', '516.354.2858', '516.776.0587', '1022', '02/02/19', '0214', '0303', '5.25', '9.95', '8.75', '8.75', '32.70', '2.82', '35.52']
# Products ['516.354.2858']
# Companies []
# Locations []
# Dates ['1902-01-01 00:00:00', '2019-02-02 00:00:00']
# MAX Value 35.52
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [4327.0, 78521.0, 215406.0, 63031.0, 127.0, 5.25, 5.25, 126.0, 4.95, 4.95, 10.2, 0.84, 11.04, 20.0, -8.96]
# Verbs: ['krist']
# Nouns: ['brownsvil', 'station1', 'rep', 'qti', 'pari', 'classiqu', 'tender', 'number', 'purchas']
# Cardinal Values: ['4327', '77/83', '78521', '215406', '4/24/2016', '63031', '127', '5.25', '5.25', '126', '4.95', '4.95', '10.20', '0.84', '11.04', '20.00']
# Products ['956-350-8686', '956-543-5089']
# Companies ['umix', 'userkrist']
# Locations []
# Dates ['2016-04-24 00:00:00']
# MAX Value 20.0
#
#  ###
#
# Currency Linked Value: ['$2.17', '$3.00']
# Raw Values: [1249.0, 1248.0, 176.0, 262.0, 1110.0, 2.0, 2.0, 1249.0]
# Verbs: ['hamb']
# Nouns: ['number', 'burger', 'santa', 'clara', 'kevin', '%', 'tender']
# Cardinal Values: ['1249', '1248', '176', '262', '1110', '2.00', '2.00', '.25', '2.17', '3.00', '1249']
# Products []
# Companies ['inst pro counter-tak']
# Locations ['burger santa clara']
# Dates []
# MAX Value 3.0
#
#  ###
#
# Currency Linked Value: ['$45.58']
# Raw Values: [48183.0, 2441.0, 734.0, 22037.0, 22037.0, 2.5, 5.0, 6.0, 0.0, 7.0, 0.0, 12.5, 10.0, 43.0, 2.58, 128.0, 74812.0]
# Verbs: ['hom']
# Nouns: ['grotto', 'pizzeria', 'van', 'triniti', 'reg', 'pepper', 'salad', 'app', 'chees', 'carnivor', 'draft', 'bread', 'reg', 'margherita', 'licket']
# Cardinal Values: ['48183', '2441', '734', '22037', '22037', '2.50', '5.00', '6.00', '0.00', '7.00', '0.00', '12.50', '10.00', '43.00', '2.58', '45.58', '128', '5/12/2017', '74812']
# Products ['capres chees carnivor draft', '0.00 12.50']
# Companies ['grotto pizzeria tavern trenton', '2441 van hom']
# Locations []
# Dates ['2017-05-12 00:00:00']
# MAX Value 45.58
#
#  ###
#
# Currency Linked Value: ['$47.02']
# Raw Values: [771.0, 7306.0, 201.0, 80110.0, 10.99, 12.99, 3.98, 14.99, 0.99, 8.99, 35.95, 2.98, 38.93, 8.09, 105649.0]
# Verbs: ['masala']
# Nouns: ['spice', 'newark', 'avenu', 'jersey', 'com', 'dal', 'fri', 'paneer', 'butter', 'rice', 'biryani', 'rice', 'orderiot', 'iolal', '%', 'return', 'cancel', 'onc', 'onli', 'faulti']
# Cardinal Values: ['771', '07306', '201', '80110', '10.99', '12.99', '3.98', '14.99', '8.99', '35.95', '2.98', '38.93', '18', '8.09', '47.02', '7/26/2019', '105649']
# Products []
# Companies ['deccan', 'deccan', 'orderiot iolal', 'onc']
# Locations []
# Dates ['2019-07-26 00:00:00']
# MAX Value 47.02
#
#  ###
#
# Currency Linked Value: ['$19.95', '$20.95', '$21.95', '$62.85', '$6.91', '$69.76']
# Raw Values: [1125.0, 22314.0, 7037179740.0, 16.0, 34.0]
# Verbs: ['alexandria']
# Nouns: ['hawwi', 'restau', 'goulash', 'dullet', 'oredit', 'ade']
# Cardinal Values: ['1125', '22314', '7037179740', '85347p', '016', '19.95', '20.95', '34', '21.95', '62.85', '6.91', '69.76']
# Products []
# Companies ['hawwi', 'mosa']
# Locations []
# Dates []
# MAX Value 69.76
#
#  ###
#
# Currency Linked Value: ['$29.88']
# Raw Values: [383.0, 94015.0, 650.0, 1951.0, 2406.0, 29.88, 29.88, 4.48, 3.01, 32.89, 37.37, 100.0, 62.63, 1951.0]
# Verbs: ['dinner']
# Nouns: ['moonstar', 'gellert', 'blvd', 'tab332', 'qty/lb', 'weekday', '%', 'tax8.75', '%']
# Cardinal Values: ['383', '94015', '650', '992-2888', '1951', '2406', '29.88', '29.88', '29.88', '15', '4.48', '3.01', '32.89', '37.37', '100.00', '62.63', '10/29/2018', '1951']
# Products ['992-2888']
# Companies ['moonstar', 'qty']
# Locations []
# Dates ['1951-01-01 00:00:00', '2018-10-29 00:00:00', '1951-01-01 00:00:00']
# MAX Value 100.0
#
#  ###
#
# Currency Linked Value: ['2@$3.50', '$7.00', '$10.24', '$10.24', '$27.48', '$2.67', '$30.15', '15%=$4.52', '18%-$5.43', '20%-$6.03']
# Raw Values: [2011.0, 98201.0, 1236.0]
# Verbs: ['everett', 'chang', 'delight', 'red', ']']
# Nouns: ['thai', 'gusto', 'thai', 'gusto', 'hewitt', 'tel', 'fax', 'welcom', 'thai', 'gusto', 'prach', 't.1', 'chicken', 'rice', ']', 'l28', 'chicken', 'rice', '%', '%', '%', 'thi']
# Cardinal Values: ['2011', '98201', '6/16/2017', '1236', '2', '3.50', '7.00', '10.24', '10.24', '27.48', '2.67', '30.15', '15', '4.52', '18', '5.43', '20', '6.03']
# Products ['guid', '20%-$6.03']
# Companies []
# Locations []
# Dates ['2011-01-01 00:00:00', '2017-06-16 00:00:00']
# MAX Value 30.15
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [14727.5, 91340.0, 27.96, 3.16, 31.12, 2.8, 33.92, 3.39, 5.09, 6.78]
# Verbs: ['coke']
# Nouns: ['asia', 'buffet', 'rinaldi', 'st', 'weekend', 'dinner', 'dinner', 'tax9x', 'express', '%', '%', '%']
# Cardinal Values: ['14727.5', '91340', '27.96', '3.16', '31.12', '2.80', '33.92', '10', '3.39', '15', '5.09', '20', '6.78']
# Products ['3.16']
# Companies ['coke', 'american express']
# Locations ['asia']
# Dates []
# MAX Value 33.92
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [1617.0, 730.0, 308.0, 5.99, 0.25, 0.4, 6.64, 0.63, 7.27, 7.27, 0.0, 499206.0, 7.27, 31341.0, 939988.0]
# Verbs: ['lettica', 'sauc', 'read', 'seq']
# Nouns: ['mcdonald', 'eslla', 'h3100', 'estpp', 'tel', 'side', 'itr', 'chee', 'requ', 'leaf', 'mac', 'subtota', 'cashless', 'mer', 'issuer', 'd.iith', 'bjw', 'debit', 'chip', 'aid', 'a0042', 'mcdonald', 'avai', 'ort', 'jbereat']
# Cardinal Values: ['1617', '33', '1053', '730', '0308', '5.99', '0.25', '0.40', '6.64', '0.63', '7.27', '7.27', '0.00', '499206', '7.27', '31341', '0939988']
# Products ['itr chee 5.99', 'sauc']
# Companies ['mcdonald', 'requ leaf lettica', 'mac', 'amdl', 'mcdonald']
# Locations []
# Dates []
# MAX Value 7.27
#
#  ###
#
# Currency Linked Value: ['$21.47', '$0.50', '$0.50', '$0.50', '$0.50', '$7.89', '$3.09', '$5.49-', '$5.49', '$0.99', '$0.99', '$4.39', '$51.82', '$51.82']
# Raw Values: [7701.0, 90201.0, 154.0, 1924.0]
# Verbs: []
# Nouns: ["chris'g", 'hamburg', 'atlant', 'ave', 'cudahi', 'clerk']
# Cardinal Values: ['7701', '90201', '07/22/2018', '21.47', '0.50', '0.50', '0.50', '0.50', '7.89', '3.09', '5.49', '0.99', '0.99', '4.39', '51.82', '51.82', '00154', '1924']
# Products []
# Companies ['hamburg 7701 atlant ave', 'cudahi']
# Locations []
# Dates ['2018-07-22 00:00:00', '1924-01-01 00:00:00']
# MAX Value 51.82
#
#  ###
#
# Currency Linked Value: ['$42.75', '$41.31']
# Raw Values: [96707.0, 808.0, 24016.0, 1246.0, 8.0, 19.0, 2.0, 12.0, 13.0, 9.75, 4.0, 14.0, 15.0, 16.0, 17.0, -3.3, 18.0, 1.86, 19.0, 20.0, 30.0, 40.0, 300.0]
# Verbs: ['kapolei', 'elijah']
# Nouns: ['wau', 'place', 'ictices', 'id', 'acknowl', 'f//6f', 'salad', 'ranch', 'wagyu', 'cheeseburg', 'medium', '%', 'fri', 'onions', 'bacon', 'plz', 'drink', 'day', 'tea', 'ohana', 'breakfast', 'hnlko', '%', 'pou', 'moi', 'endra', 'regu', 'compris', 'g', 'votr', 'wir', 'w']
# Cardinal Values: ['92-161', '96707', '808', '01/11/2019', '24016', '1246', '44/0', '8.00', '19.00', '20', '2.00', '12.00', '13.00', '9.75', '4.00', '14.00', '15.00', '42.75', '16.00', '17.00', '-3.30', '4712', '18.00', '1.86', '19.00', '20.00', '41.31', '30.00', '40.00', '300', '443/']
# Products []
# Companies ['ohana breakfast -3.30', 'un']
# Locations []
# Dates ['2019-01-11 00:00:00']
# MAX Value 42.75
#
#  ###
#
# Currency Linked Value: []
# Raw Values: []
# Verbs: []
# Nouns: []
# Cardinal Values: []
# Products []
# Companies []
# Locations []
# Dates []
# MAX Value 0
#
#  ###
#
# Currency Linked Value: ['$3.00', '$7.00', '$2.00', '$2.99', '$2.99', '$1.00', '$2.99', '$1.00', '$2.99', '$2.99', '$28.95', '$2.03', '$30.98']
# Raw Values: [2145.0, 6179661387.0]
# Verbs: ['somervil', 'pescado', 'pollo', 'asada', 'chorizo', 'pastor', 'pollo', 'cochinita', 'carnita']
# Nouns: ['rincon', 'mexicano', 'taco', 'taco', 'tuesday', 'taco', 'carn', 'taco', 'taco', 'tuesday', 'taco', 'tuesday', 'taco', 'taco']
# Cardinal Values: ['02145', '6179661387', '71946p', '3.00', '7.00', '2.00', '2.99', '2.99', '1.00', '2.99', '1.00', '2.99', '2.99', '28.95', '2.03', '30.98', '7jtog7zx6anr8']
# Products []
# Companies []
# Locations []
# Dates ['2145-01-01 00:00:00']
# MAX Value 30.98
#
#  ###
#
# Currency Linked Value: ['$94.78']
# Raw Values: [186.0, 516.0, 11001.0, 3.5, 9.95, 12.95, 10.95, 23.95, 25.95, 87.25, 7.53, 44405.0]
# Verbs: ['flora', 'toke', 'escargot', 'arancio']
# Nouns: ['villa', 'dest', 'jericho', 'park', 'jerri', 'coffe', 'glass', 'wine', 'junbo', 'coctail', 'shriap', 'zingaria', 'duckl', 'ala', 'total', 'villa', 'agair']
# Cardinal Values: ['186', '516', '11001', '3.50', '9.95', '12.95', '10.95', '23.95', '25.95', '87.25', '7.53', '94.78', '12/8/2017', '44405']
# Products ['jerri 3.50']
# Companies ['junbo coctail', 'duckl ala arancio', 'villa']
# Locations []
# Dates ['2017-12-08 00:00:00']
# MAX Value 94.78
#
#  ###
# Currency Linked Value: []
# Raw Values: [1220.0, 90254.0, 123.0, 501.0, 1388.0, 5.0, 8.0, 11.0, 12.0, 4.5, 40.5, 40.5, 3.85, 44.35]
# Verbs: ['hermosa', 'sophi']
# Nouns: ['laurel', 'hermosa', 'beach', 'hermosa', 'beach', 'beach', 'tel', 'waiter', 'cust', 'btl', 'beer', 'brussel', 'sprout', 'cantones', 'tender', 'grill', 'chees', 'websit', 'www', 'laureltavern.col']
# Cardinal Values: ['1220', '90254', '01/12/19', '123', '501', '1388', '5.00', '8.00', '11.00', '12.00', '4.50', '40.50', '40.50', '3.85', '44.35']
# Products ['btl', '3.85']
# Companies ['laurel tavern hermosa beach', 'websit']
# Locations []
# Dates ['2019-01-12 00:00:00']
# MAX Value 44.35
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [1717.0, 11003.0, 168.0, 1.19, 1.19, 0.62, 5.75, 9.5, 9.5, 168.0, 2014.0]
# Verbs: ['.62', 'txtl']
# Nouns: ['thing', 'dutch', 'brdi', 'call', 'mac', 'coll', 'grn', 'corn', 'bread', 'fri', 'mar', 'reg1']
# Cardinal Values: ['1717', '11003', '168', '1.19', '1.19', '5.75', '9.50', '9.50', '0168', '2014', "19'1"]
# Products ['168 mac&chz']
# Companies []
# Locations []
# Dates ['1717-01-01 00:00:00', '2014-01-01 00:00:00']
# MAX Value 9.5
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [8030.0, 27713.0, 984.0, 1225.0, 15.49, 8.99, 18.99, 43.47, 3.26, 46.73, 46.73]
# Verbs: ['salad', 'fajita', 'pollo']
# Nouns: ['anastashia', 'taco', 'ground', 'beef', 'chicken', 'pechuga', 'ask', 'julio', 'join', 'ton', 'reward', 'earn']
# Cardinal Values: ['8030', '27713', '984', '05/18/2019', '57/1', '1225', '15.49', '8.99', '18.99', '43.47', '3.26', '46.73', '46.73']
# Products []
# Companies []
# Locations []
# Dates ['2019-05-18 00:00:00', '2057-01-01 00:00:00']
# MAX Value 46.73
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [75015.0, 5.8, 15.8, 5.6, 5.8, 5.4, 15.4, 15.45, 1.55, 17.0]
# Verbs: ['char', '+17.00']
# Nouns: ['lafourc', 'alain', 'note', 'penrter', 'ou5', '*17.00', 'h.t', 'tva', 'dont', 'tva', 'ttc', 'merci', 'votr']
# Cardinal Values: ['75015', '5.80', '15.80', '5.60', '5.80', '5.40', '15.40', '01.48.28.44.81']
# Products ['ou5 orant 5.40 15.40']
# Companies ['coca-cola', 'tva', 'prix']
# Locations []
# Dates []
# MAX Value 15.8
#
#  ###
#
# Currency Linked Value: ['$1.45', '$1.45', '$5.50', '$4.50', '$2.95', '$2.95', '$2.50', '$2.95', '$24.25', '$2.13', '$2638']
# Raw Values: [1084.0, 10704.0, 914.0, 1101.0]
# Verbs: ['coffe', 'toast']
# Nouns: ['diner200o', 'deiver', 'pay', 'yonker', 'avenu', 'yonker', 'copi', 'fashion', 'side', 'home', 'egg', 'number', 'number', 'ssahdx', 'rder', 'start', 'august', 'ndihsi', 'comment', 'comment', 'home']
# Cardinal Values: ['1084', '10704', '914', '1.45', '1.45', '5.50', '0ld', '4.50', '2.95', '2.95', '2.50', '2.95', '24.25', '2.13', '2638', '1101']
# Products ['237-5055', 'copi']
# Companies ['argonaut diner200o', 'yonker avenu yonker 10704']
# Locations []
# Dates []
# MAX Value 24.25
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [30.0, 76011.0, 1304.0, 817.0, 35.0, 1211.0, 15.95, 18.95, 13.95, 48.85, 3.91, 52.76, 1245.0, 7.91, 9.5, 10.55]
# Verbs: ['seafood', 'arlington', 'combo']
# Nouns: ['pappadeaux', 'pappoa', 'r', 'seafood', 'kitchen', 'pappadeaux', 'copeland', 'www.pappadeaux.com', 'svrck', 'parti', 'sarah', 'lump', 'crab', 'spinach', 'dip', 'lunch', 'shrimp', 'andouil', 'cajun', 'pappadeaux', '%', '%', '%', 'validation']
# Cardinal Values: ['030', '76011', '1304', '817', '0035', '1211', '11/18/17', '15.95', '18.95', '13.95', '48.85', '3.91', '52.76', '11/18', '1245', '15', '7.91', '18', '9.50', '20', '10.55']
# Products []
# Companies ['pappadeaux pappoa r seafood kitchen pappadeaux', 'svrck parti 1211']
# Locations []
# Dates ['2017-11-18 00:00:00']
# MAX Value 52.76
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [1291.0, 34124.0, 177437.0, 139.0, 12.0, 151.0, 13.89, 164.89, 200.0, 35.11]
# Verbs: ['everett', 'orang']
# Nouns: ['store', 'panda', 'express', 'chow', 'mein', 'rice', 'fried/c', 'mein', 'ckn', 'grill', 'shrimp', 'entre', 'opinion', 'call', 'pandaexpress.com/gu']
# Cardinal Values: ['1291', '3/16/2013', '34124', '177437', '139.00', '12.00', '151.00', '13.89', '164.89', '200.00', '35.11', '1-888-51-panda72632']
# Products ['ckn grill', 'entre valu', '1-888-']
# Companies ['panda express']
# Locations []
# Dates ['2013-03-16 00:00:00']
# MAX Value 200.0
#
#  ###
#
# Currency Linked Value: ['$20.00**']
# Raw Values: [12502.0, 33186.0, 305.0, 71410.0, 1082.0, 1041.0, 17.8]
# Verbs: ['welcom', "puf'chas"]
# Nouns: ['micro', 'demo', 'system', 'kendal', 'miami', "sep07'18", 'type', 'acct', 'tran', 'type', 'purchas', 'tran', 'iii008007193348', 'auth', 'code', 'melani', '*no', 'signatur', 'requir']
# Cardinal Values: ['12502', '33186', '305', '071410', '1082', '1041', '17.80', '20.00**']
# Products ['welcom yogurtland']
# Companies ['micro demo system', 'purchas tran key iii008007193348 auth']
# Locations ['north kendal']
# Dates ['2010-07-14 00:00:00']
# MAX Value 17.8
#
#  ###
#
# Currency Linked Value: ['$11.38', '$0.70', '$12.08', '$0.00', '$0.97', '$13.05', '$13.05', '$0.00']
# Raw Values: [1100375.0, 916.0, 8105.0, 74242.0, 3100.0, 3625.0]
# Verbs: ['ckn', 'sce']
# Nouns: ['carl', 'madison', 'regist', 'tender', 'drivethru', 'santa', 'santa']
# Cardinal Values: ['1100375', '916', '8105', '12/19/2016', '74242', '3100', '3625', '11.38', '0.70', '12.08', '0.00', '0.97', '13.05', '13.05', '0.00']
# Products ['962-3415']
# Companies ['american green chile', 'santa sce']
# Locations []
# Dates ['2016-12-19 00:00:00']
# MAX Value 13.05
#
#  ###
#
# Currency Linked Value: ['$7.99', '$7.99', '$1.00', '$2.50', '$3.50', '$22.98', '$1.61', '$3.45', '$28.04', '$28.04']
# Raw Values: [77736.0, 147.0, 33196.0, 7865174888.0, 211209.0]
# Verbs: ['miami', 'www.sukhothaius.com', 'egg', 'miso']
# Nouns: ['sukhotha', 'sukhothai', 'sushi', 'fusion', 'unit', 'http//www.sukhothaius.com', 'onlin', 'chicken', 'fri', 'rice', 'lunch', 'california', 'tropic', 'lunch', 'toston', 'perrier', 'water', 'fee', 'tables', '%']
# Cardinal Values: ['77736', '147', '33196', '7865174888', '20226p', '211209', '7.99', '7.99', 'two', '1.00', '2.50', '3.50', '22.98', '1.61', '3.45', '15.0', '28.04', '28.04']
# Products []
# Companies ['california tropic', 'perrier']
# Locations ['sukhotha sukhothai sushi']
# Dates ['2009-12-21 00:00:00']
# MAX Value 28.04
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [75015.0, 5.8, 15.8, 5.6, 5.8, 5.4, 15.4, 15.45, 1.55, 17.0]
# Verbs: ['char', '+17.00']
# Nouns: ['lafourc', 'alain', 'note', 'penrter', 'ou5', '*17.00', 'h.t', 'tva', 'dont', 'tva', 'ttc', 'merci', 'votr']
# Cardinal Values: ['75015', '5.80', '15.80', '5.60', '5.80', '5.40', '15.40', '01.48.28.44.81']
# Products ['ou5 orant 5.40 15.40']
# Companies ['coca-cola', 'tva', 'prix']
# Locations []
# Dates []
# MAX Value 15.8
#
#  ###
#
# Currency Linked Value: ['$13.95', '$3.00', '$19.95', '$17.00', '$16.00', '$69.90', '-$17.95', '$3.44', '$73.34', '$55.39']
# Raw Values: [7022.0, 201.0, 832869.0]
# Verbs: ['chicharron', 'frito', 'chicken', 'plancha', 'ensalada']
# Nouns: ['fairview', 'check832869', 'te02/11/19', 'table23', 'serverdaniela', 'guaca', 'pargo', 'cebolla', 'cebolla', 'roja', 'mar', 'toston', 'toston', 'togo', 'salmon']
# Cardinal Values: ['07022', '201', '832869', '13.95', '3.00', '19.95', '17.00', '16.00', '69.90', '17.95', '3.44', '73.34', '55.39']
# Products []
# Companies ['fairview', 'te02/11/19', 'table23 serverdaniela guaca chicharron', 'roja mar']
# Locations []
# Dates []
# MAX Value 73.34
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [2019.0, 233.0, 1019.0, 12.5, 12.0, 24.5, 2.17, 0.0, 26.67, 11477215613.0]
# Verbs: []
# Nouns: ['cater', 'soul', 'yonker', 'yonkers', 'june', 'adnin', 'mac', 'chees', 'yam', 'mac', 'chees']
# Cardinal Values: ['1131b', '914-237-5083', '2019', '233', '1019', '12.50', '12.00', '24.50', '2.17', '0.00', '26.67', '0011477215613']
# Products ['914-237-5083']
# Companies ['mz0a', 'mac chees']
# Locations []
# Dates ['2019-01-01 00:00:00']
# MAX Value 26.67
#
#  ###
#
# Currency Linked Value: ['$4717', '$02']
# Raw Values: [7635.0, 818.0, 9.99, 9.99, 0.95, 10.94, 11.0]
# Verbs: ['.95']
# Nouns: ['church', 'winnetka', 'canoga', 'park', 'txtl', "may.21'19", 'reg2']
# Cardinal Values: ['4717', '818', '25c', '9po', '9.99', '9.99', '10.94', '11.00', '02']
# Products ['576-0490 25c']
# Companies ["church'"]
# Locations []
# Dates []
# MAX Value 11.0
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [301.0, 347.0, 4.49, 7.2, 7.2, 1.89, 20.78, 0.0, 1.25, 0.0, 22.03, 22.03, 0.0]
# Verbs: ['nid', 'paid']
# Nouns: ['yum', 'laurol', 'bowvor', 'lautel', 'walk', 'yumn', 'steak', 'chees', 'wings', 'muamnbo', 'sauceet', 'homemac', 'hall', 'hall', 'subtor', 'bev', 'bev', 'receiv', 'cliang']
# Cardinal Values: ['20/06', '301', '3011773', '6002', 'one', '347', '4.49', '7.20', '7.20', '1.89', '20.78', '0.00', '1.25', '0.00', '22.03', '22.03', '0.00']
# Products []
# Companies ['yum', 'chees', 'sauceet homemac hall hall', 'bev']
# Locations []
# Dates []
# MAX Value 22.03
#
#  ###
#
# Currency Linked Value: ['$12.00', '$8.00', '$14.00', '$3.40', '$30.60', '$6.12', '$2.14', '$38.86']
# Raw Values: [17861.0, 33160.0, 539.0]
# Verbs: ['aventura', 'bean']
# Nouns: ['pay', 'discov', 'wherev', 'gow', 'araxi', 'burger', 'biscayn', 'aventura', 'valeri', 'vanilla', 'burger', 'rout', 'burger', '%', '%', '%', 'power', 'toast']
# Cardinal Values: ['17861', '33160', '03/17/19', '539', '12.00', '4oz', '8.00', '14.00', '8oz', '3.40', '10', '10.00', '30.60', '6.12', '18.00', '2.14', '38.86']
# Products []
# Companies ['discov', 'vanilla burger bean']
# Locations []
# Dates ['2019-03-17 00:00:00']
# MAX Value 38.86
#
#  ###
# Currency Linked Value: ['$85']
# Raw Values: [730.0, 730.0, 45757.0, 940.0, 30062.0, 48.0, 28.5, 3.0, 79.5, 5.57, 85.07, 85.07, 17.48]
# Verbs: ['megan', '@', 'goos', '@']
# Nouns: ['kitchen', 'patio', 'com', 'mass', 'canbrid9e-868-8800', 'cambr', 'ver', 'sle', 'manhattan', 'mark', 'grey', 'rock', 'prtor', 'luin']
# Cardinal Values: ['730', '730tavern.com', '730', '09/23/2017', '45757', '940', '3/1', '30062', '16.00', '48.00', '3maker', '9.50', '28.50', '85', '1.00', '3.00', '79.50', '5.57', '85.07', '85.07', '22x', '17.48', '2ox']
# Products ['canbrid9e-868-8800']
# Companies ['idg', 'sle', '@16.00']
# Locations []
# Dates ['2017-09-23 00:00:00']
# MAX Value 85.07
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [2501.0, 90404.0, 730.0, 20027.0, 3.65, 27.95, 3.65, 11.95, 35.75, 82.95, 8.5, 91.45, 91.45]
# Verbs: ['monica', 'coke', 'coke']
# Nouns: ['daili', 'grill', 'daili', 'grill', 'colorado', 'santa', 'dana', 'rib', 'crispi', 'rib', 'eye', 'steak', 'broccoli', 'becom', 'fan', 'review', 'yelp', 'sign', 'dailygrill.com', 'receiv', 'promot']
# Cardinal Values: ['2501', '90404', '11/01/2018', '54/1', '730', '20027', '3.65', '27.95', '3.65', '11.95', '35.75', '82.95', '8.50', '91.45', '91.45']
# Products ['3.65', 'coke 3.65']
# Companies ['coke']
# Locations []
# Dates ['2018-11-01 00:00:00', '2054-01-01 00:00:00']
# MAX Value 91.45
#
#  ###
#
# Currency Linked Value: ['$6.00', '+$4.00', '$6.00', '+$4.00', '$54.00', '+$0.00', '+$0.00', '$74.00', '$3.49', '$77.49', '$38.75']
# Raw Values: [426.0, 96707.0, 808.0, 547.0]
# Verbs: ['daiquir']
# Nouns: ['kajun', 'kapolei', 'kapolei', 'chenay', 'tequila', 'strawberri', 'vodca', 'kickir', 'sauc']
# Cardinal Values: ['91-5431', '426', '96707', '808', '7/18/19', '547', '6.00', '4.00', '6.00', '4.00', '54.00', '0.00', '0.00', '74.00', '3.49', '77.49', '38.75']
# Products []
# Companies ['kickir sauc']
# Locations ['kapolei parkway']
# Dates ['2019-07-18 00:00:00']
# MAX Value 77.49
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [124541.0, 332114.0, 346.0, 121300.0, 2.49, 10.49, 1.0, 75.0, 10.49, 25.22, 1.74, 0.0, 0.0, 1.74, 26.96]
# Verbs: []
# Nouns: ['sport', 'hollywood', 'ate', 'theck', 'person', 'soda', 'chees', 'onion', 'chix', 'cheesesteak', 'liquor']
# Cardinal Values: ['09/08/2017', '124541', '332114', '346', '121300', '2.49', '10.49', '1.00', '075', '10.49', '25.22', '1.74', '0.00', '0.00', '1.74', '26.96']
# Products []
# Companies ['chees', 'chix']
# Locations []
# Dates ['2017-09-08 00:00:00', '2000-12-13 00:00:00', '1975-01-01 00:00:00']
# MAX Value 26.96
#
#  ###
#
# Currency Linked Value: ['$10.00', '$10.00', '$0.70', '$10.70', '$10.70']
# Raw Values: [7601.0]
# Verbs: ['hackensack']
# Nouns: ['gener', 'street', 'check555149', 'date04/10/16', 'veroniqu', 'boneless', 'choos', 'gener', 'tim']
# Cardinal Values: ['07601', '10.00', '10.00', '0.70', '10.70', '10.70']
# Products []
# Companies []
# Locations []
# Dates []
# MAX Value 10.7
#
#  ###
#
# Currency Linked Value: ['$94.18']
# Raw Values: [11001.0, 106.0, 1075.0, 7.75, 6.0, 9.95, 9.95, 5.95, 21.95, 24.95, 86.5, 7.68]
# Verbs: ['tap', 'sizzl']
# Nouns: ['jericho', 'park', 'www.nancysrestaurant.net', 'tom', 'moon', 'mozzarella', 'tomato', 'pork', 'quesadilla', 'onion', 'soup', 'pork', 'chop', 'hanger']
# Cardinal Values: ['11001', '106', '1075', '09/24/2016', '7.75', '6.00', '9.95', '9.95', '5.95', '21.95', '24.95', '86.50', '7.68', '94.18']
# Products ['imp']
# Companies ['nanoy', 'sizzl']
# Locations []
# Dates ['2016-09-24 00:00:00']
# MAX Value 94.18
#
#  ###
#
# Currency Linked Value: ['$22.50', '$27.00', '$49.50', '$2.97', '$52.47', '$886170', '$52.47', '$0.00']
# Raw Values: [67.5, 27.0, 137.0]
# Verbs: []
# Nouns: ['primo', 'b14', 'darwin', 'table10', 'check13', 'pren', 'glass', 'vecoti', 'darwin']
# Cardinal Values: ['5/3/19', '67.50', '22.50', '027.00', '27.00', '49.50', '2.97', '52.47', '886170', '52.47', '0.00', '137']
# Products []
# Companies []
# Locations []
# Dates ['2019-05-03 00:00:00']
# MAX Value 67.5
#
#  ###
#
# Currency Linked Value: ['$4.00', '$5.00', '$2.50', '$8.85', '$8.35', '$0.75', '$15.70', '$7.85', '$5.00', '$0.75', '$4.35', '$51.25', '$5.25', '$56.50', '$60.00', '$3.50']
# Raw Values: [1955.0, 25.0, 2018.0, 90404.0, 1147.0, 310.0]
# Verbs: ['monica', 'pickup', 'burger', 'fri']
# Nouns: ['jjo', 'broadway', 'jan', 'santa', 'www.bigjosburgers.com', 'shirley', 'qixi', 'turkey', 'combo', 'grill', 'grill', 'onion', 'chil']
# Cardinal Values: ['1955', '25', '2018', '90404', '1147', '310', '4.00', '5.00', '2.50', '8.85', '8.35', '0.75', '15.70', '7.85', '5.00', '0.75', '4.35', '51.25', '5.25', '56.50', '60.00', '3.50']
# Products ['90404', '310', '828-3191']
# Companies []
# Locations []
# Dates ['1955-01-01 00:00:00', '2018-01-01 00:00:00']
# MAX Value 60.0
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [519.0, 195.0, 5.99, 6.99, 6.99, 6.99, 1.19, 2.43, 30.58, 40.0]
# Verbs: ['cornbread']
# Nouns: ['ter', 'thing', 'fulton', 'ave', 'r', 'b', 'meal', 'ice', 'tea', 'meal', 'g0p', 'sierra', 'fixn', 'mac', 'chz', 'meal', 'ice', 'tea', 'rice', 'meal', 'ice', 'tea', 'fixn', 'mac', 'chz', 'coll']
# Cardinal Values: ['519', '50pc', '195', '100p', '2pc', '5.99', '200p', '50p', '3wing', '6.99', '3wing', '6.99', '6.99', '1.19', '2.43', '30.58', '40.00']
# Products ['2pc', '50p', '3wing meal 6.99']
# Companies ['fulton ave', '100p', 'g0p sierra fixn']
# Locations []
# Dates []
# MAX Value 40.0
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [19930.0, 302.0, 5033.0, 753.0, 8.0, 12.0, 26.0, 11.0, 12.0, 12.0, 8.0, 30.0, 14.0, 19.0, 12.0, 164.0, 12.0, 152.0, 0.0]
# Verbs: ['garfield', 'margarita', 'guacamol', 'asada', 'shrimp', 'chicken']
# Nouns: ['zoca', 'beach', 'www', 'zoca.restauran', 'fli', 'dog', 'numero', 'btl', 'recip', 'sandia', 'totem', 'honey', 'bee', 'queso', 'fresco', 'queso', 'fundido', 'street', 'corn', 'dip', 'salsa', 'molcajet', 'taquito', 'carn', 'taquito', 'baja', 'california', 'mole', 'enchilada', 'quesadilla', 'complimentari', 'comp', 'queso', 'fundido', 'street', 'corn', 'dip']
# Cardinal Values: ['19930', '302', '5033', '7/30/19', '753', '31/2', '8.00', '12.00', '013.00/ea', '26.00', '11.00', '12.00', '12.00', '8.00', '015.00/ea', '30.00', '14.00', '19.00', '12.00', '164.00', '12.00', '152.00', '0.00']
# Products ['616-2120']
# Companies ['btl 8.00 hous recip', 'sandia margarita 013.00', 'taquito baja', 'complimentari comp']
# Locations []
# Dates ['2019-07-30 00:00:00']
# MAX Value 164.0
#
#  ###
#
# Currency Linked Value: ['$4.00', '$4.75', '$8.75', '$0.83', '$9.58']
# Raw Values: [242.0, 310.0, 242019.0, 1029.0]
# Verbs: ['llc', 'aux']
# Nouns: ['parisien', 'larchmont', 'kimberli', 'jan', 'ywg5', 'croissant', 'cappucino', '%', 'custom', 'copi']
# Cardinal Values: ['242', '310', '242019', '1029', '4.00', '4.75', '8.75', '9.5', '0.83', '9.58']
# Products ['kimberli', 'copi']
# Companies ['cafe parisien larchmont llc', 'larchmont']
# Locations []
# Dates []
# MAX Value 9.58
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [590.0, 541.0, 706.0, 20071.0, 5.0, 4.75, 7.0, 4.75, 15.0, 36.5, 1.1, 37.6, 37.0]
# Verbs: ['amber', 'noodl', 'taco']
# Nouns: ['dera', 'breweri', 'clover', 'lane', 'ashland.orecon', 'hope', 'glass', 'imp', 'stout', 'ashland', 'butter', 'oatmeal', 'stout', 'mahi', 'mahi', 'anc', 'cheer', 'caldera', 'bottl', 'drive', 'breweri', 'growler', 'sell']
# Cardinal Values: ['590', '541', '1/1', '12/28/2017', '706', '20071', '5.00', '4.75', '7.00', '4.75', '15.00', '36.50', '1.10', '37.60', '37']
# Products []
# Companies ['12/28/2017', 'mahi mahi', 'bal anc']
# Locations []
# Dates ['2017-12-28 00:00:00']
# MAX Value 37.6
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [84.0, 6.0, 6.0, 0.4, 1.15, 1946.0]
# Verbs: ['svrck']
# Nouns: ['april', 'decemb', 'parti', 'dwyer', 'cup', 'chowder', 'grat', 'lunch', 'dinner', 'reserv']
# Cardinal Values: ['0084', '1147a', '06/10/17', '6.00', '6.00', '0.40', '1.15', '06/10', '139ptotal', '1946']
# Products ['1.15 06/10']
# Companies ['landfal april decemb', 'parti dwyer', 'grat']
# Locations []
# Dates ['2017-06-10 00:00:00', '1946-01-01 00:00:00']
# MAX Value 6.0
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [1660.0, 629.0, 20018.0, 12.0, 11.0, 27.95, 23.75, 74.7, 6.0, 2.8, 83.5, 83.5, 0.5]
# Verbs: ['sauv', 'scallop', 'chicken']
# Nouns: ['street', 'jake', 'karma', 'douglass', 'pkli', 'curri', 'pkli', 'piri', 'piri', '%', '%', 'support', 'increas', 'wage', 'whi', 'www.wnthosp.com/rttd']
# Cardinal Values: ['1660', '12/17/2017', '24/1', '629', '20018', '12.00', '11.00', '27.95', '23.75', '74.70', '6.00', '3.75', '2.80', '83.50', '83.50', '3.75']
# Products ['pkli piri piri']
# Companies []
# Locations []
# Dates ['2017-12-17 00:00:00']
# MAX Value 83.5
#
#  ###
#
# Currency Linked Value: ['$3.96', '$4.75', '$5.27', '$5.80']
# Raw Values: [17588.0, 91748.0, 125.0, 2060012.0, 12.19, 11.89, 24.08, 2.29, 26.37, 26.37]
# Verbs: ['waffles4']
# Nouns: ['chili', 'puent', 'hill', 'castleton', 'industryca', 'jose', 'type', 'chicken', '%', '%', '%', '%', 'chip', 'salsa', 'gift', 'activ', 'delay', 'hours', "we'r", 'dotng']
# Cardinal Values: ['17588', '91748', '09/15/2018', '33/1', '125', '2060012', '12.19', '11.89', '24.08', '2.29', '26.37', '26.37', '15', '3.96', '18', '4.75', '20', '5.27', '22', '5.80']
# Products ['2.29', '26.37']
# Companies ['chili', 'everi chilis.com/reward gift activ']
# Locations []
# Dates ['2018-09-15 00:00:00', '2033-01-01 00:00:00']
# MAX Value 26.37
#
#  ###
# Currency Linked Value: []
# Raw Values: [403.0, 339.0, 10.75, 3.75, 9.75, 22.75, 132.25, 9476.0, 142101.0]
# Verbs: ['red', 'sda', 'scampi']
# Nouns: ['roger', 'prem', 'whtte', 'prem', 'dtet', 'ripien', 'chlcicem', 'p2rm21275', 'ling', 'pasta', 'sp16.75', 'lip', 'subtot', 'yol', 'harteadcc', 'foaeli']
# Cardinal Values: ['403', '339', '18/17', '819pn', '10.75', '3.75', '9.75', '22.75', '1/2', '132.25', '9476', '142101']
# Products []
# Companies ['mertanaccx', '819pn', 'p2rm21275']
# Locations []
# Dates []
# MAX Value 132.25
#
#  ###
#
# Currency Linked Value: ['$22.50', '$27.00', '$49.50', '$2.97', '$52.47', '$816170', '$52.47', '$0.00']
# Raw Values: [814.0, 137.0, 87.5, 27.0]
# Verbs: ['famili']
# Nouns: ['primo', 'darvin', 'table1o', 'glass', 'veggl', 'charg', 'darin', 'tahlo', 'tin']
# Cardinal Values: ['5/3/19', '814', '137', '87.50', '22.50', '027.00', '27.00', '49.50', '2.97', '52.47', '816170', '52.47', '0.00']
# Products []
# Companies ['primo famili', 'darvin']
# Locations []
# Dates ['2019-05-03 00:00:00']
# MAX Value 87.5
#
#  ###
#
# Currency Linked Value: ['$19.44']
# Raw Values: [304.0, 302.0, 247.0, 480.0, 2152.0, 3.3, 4.35, 1.6, 3.5, 1.7, 1.5, 2.05, 18.0]
# Verbs: ['escondido', 'coke', 'med']
# Nouns: ['number', 'burger', 'counter-eat', 'doldbl', 'onli', 'anim', 'coke', 'shk', '%']
# Cardinal Values: ['304', '302', '247', '480', '2152', '3.30', '3x3', '4.35', '1.60', '3.50', '1.70', '1.50', '2.05', '18.00', '8.00', '19.44']
# Products ['3.50 coke 1.70']
# Companies ['burger escondido', 'onli 1.60 anim', 'shk']
# Locations []
# Dates ['2152-01-01 00:00:00']
# MAX Value 19.44
#
#  ###
#
# Currency Linked Value: ['$15.00', '$18.00', '$9.50', '$42.50', '$3.29', '$45.79', '$45.79', '$7.65', '$53.44', '$8.50', '$54.29', '$9.35', '$55.14']
# Raw Values: [3313.0, 92626.0, 714.0, 538.0, 8444.0, 118888.0, 1216.0]
# Verbs: ['mesa', 'solo']
# Nouns: ['taco', 'maria', 'hyland', 'ave', 'ste', 'c21', 'ww.tacomaria.co', 'jesa', 'arrachera', '%', '%', '%']
# Cardinal Values: ['3313', '92626', '714', '538', '8444', '118888', '1/23/18', '1216', '15.00', '18.00', '9.50', '42.50', '3.29', '45.79', '45.79', '18.00', '7.65', '53.44', '20.00', '8.50', '54.29', '22.00', '9.35', '55.14']
# Products []
# Companies ['taco maria 3313 hyland ave.', 'ste c21 costa mesa']
# Locations []
# Dates ['2018-01-23 00:00:00']
# MAX Value 55.14
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [1623.0, 12.0, 8.0, 18.0, 13.0, 10.0, 15.0, 6.0, 82.0]
# Verbs: ['telefono', 'fritt']
# Nouns: ['bellagio', 'tav', 'coperti', 'sala', 'coperto', 'acqua', 'salmerino', 'trenett', 'pesto', 'spaghetti', 'pom', 'ragu', 'patatin', 'mancia/tip', 'prego', 'ritirar', 'alla', 'cassa']
# Cardinal Values: ['031/951888', '14/07/2019', '1623', '12.00', '8.00', '18.00', '13.00', '10.00', '15.00', '6.00', '82.00']
# Products []
# Companies ['acqua nat', 'fritt']
# Locations []
# Dates ['2019-07-14 00:00:00']
# MAX Value 82.0
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [18128.0, 90701.0, 562.0, 7.95, 14.95, 6.95, 6.95, 36.8, 3.5, 40.3]
# Verbs: ['artes1a', 'dosa']
# Nouns: ['anjappar', 'chettnad', 'pioneer', 'artesia', 'www.anjapparla.com', 'anjappar', 'c16', 'deepthi', 'devic', 'ghee', 'kid', 'wait', 'mutton', 'meal', 'aldosa', 'plain']
# Cardinal Values: ['18128', '90701', '562', '7.95', '14.95', '6.95', '6.95', '36.80', '3.50', '40.30']
# Products ['991-1801', '3.50']
# Companies ['artesia']
# Locations []
# Dates []
# MAX Value 40.3
#
#  ###
#
# Currency Linked Value: ['$17.00', '$12.00', '$4.00', '$6.00', '$3.00', '$3.90', '$42.90']
# Raw Values: [1175.0, 94706.0, 908.0, 339.0]
# Verbs: ['avenu', 'com', 'bacon']
# Nouns: ['cafe', 'eugen', 'solano', 'www.cafeeuoena', 'pork', 'side', 'bubtot']
# Cardinal Values: ['1175', '94706', '4/10/16', '908', '17.00', '12.00', '4.00', '6.00', '3.00', '339.00', '3.90', '42.90']
# Products []
# Companies ['cupen cafe eugen', 'solano avenu albani', 'www.cafeeuoena']
# Locations []
# Dates ['2016-04-10 00:00:00']
# MAX Value 339.0
#
#  ###
#
# Currency Linked Value: ['$7.99', '$2.29', '$10.28', '$0.62', '$10.90']
# Raw Values: [22825.0, 48173.0, 802.0, 2.99]
# Verbs: ['famili', 'kayak']
# Nouns: ['illag', 'river', 'villag', 'huron', 'river', 'jasmin', 'bird', 'breakfast', 'friday', 'river', 'villag', 'pay', 'regist']
# Cardinal Values: ['22825', '48173', '08/12/19', '802', '7.99', '2.29', '10.28', '0.62', '10.90', '2.99']
# Products []
# Companies ['wer illag river', 'jasmin']
# Locations []
# Dates ['2019-08-12 00:00:00']
# MAX Value 10.9
#
#  ###
#
# Currency Linked Value: ['$10.95', '$1.00', '$1.50', '$2.00']
# Raw Values: [886.0, 90640.0, 323.0, 10.0, 10.0, 0.95, 21634.0]
# Verbs: ['montebello']
# Nouns: ['mr', 'thing', 'inc', 'garfield', 'jose', 'ribey', 'steak', 'lunch', '%', '%', '%']
# Cardinal Values: ['886', '90640', '323', '10.00', '10.00', '0.95', '10.95', '6/28/2019', '21634', '10', '1.00', '15', '1.50', '20', '2.00']
# Products ['323', '477-1345']
# Companies ['garfield montebello']
# Locations []
# Dates ['2019-06-28 00:00:00']
# MAX Value 10.95
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [190.0, 11001.0, 516.0, 217510.0, 1020.0, 101244.0, 11.0, 18.0, 16.0, 4.0, 5.5, 69.5, 69.5, 6.0, 75.5]
# Verbs: ['salad']
# Nouns: ['jericho', 'park', 'tel', 'cust', 'quesadilla', 'pot', 'roast', 'chip', 'side', 'dft', 'shock', 'dft', 'guiness', 'expr', 'express', 'carci']
# Cardinal Values: ['190', '11001', '516', '217510', '02/18/17', '1020', '101244', '11.00', '18.00', '16.00', '4.00', '5.50', '15', '00', '69.50', '69.50', '6.00', '75.50']
# Products []
# Companies ['triniti', 'jericho tpke', 'ammerican expr']
# Locations []
# Dates ['2017-02-18 00:00:00', '2044-10-12 00:00:00']
# MAX Value 75.5
#
#  ###
#
# Currency Linked Value: ['$21.69']
# Raw Values: [4469.0, 90270.0, 323.0, 65193.0, 8.45, 7.95, 3.5, 0.0, 19.9, 1.79, 22.0, -0.31, 74346.0, 74418.0]
# Verbs: ['maywood']
# Nouns: ['bbq', 'slauson', 'karla', 'settl', 'combo', 'fri', 'shrimp', 'rib', 'combo', 'bbq', 'beef', 'fri', 'shrimp', 'medium', 'tender', 'creat', 'settl']
# Cardinal Values: ['4469', '90270', '323', '65193', '1/2', '1/2', '8.45', '1/2', '1/2', '7.95', '3.50', '0.00', '19.90', '1.79', '21.69', '22.00', '6/1/2013', '74346', '6/1/2013', '74418']
# Products ['323', '771-9888']
# Companies ['ohana hawaiian', 'slauson maywood']
# Locations []
# Dates ['2013-06-01 00:00:00', '2013-06-01 00:00:00']
# MAX Value 22.0
#
#  ###
#
# Currency Linked Value: ['$11.99', '$13.22']
# Raw Values: [625.0, 91105.0, 22537.0, 11.99, 11.99, 1.23, 13.22, 13.22, 0.0, 51140.0, 912121113552.0, 111414448442.0, 88.0, 40031010.0, 22537.0]
# Verbs: ['chse', 'contact.en', 'fate/tin']
# Nouns: ['pasadent', 'qti', 'size', 'ani', '-steak', '-b.m.t', 'eat', 'refer', 'issuer', 'account', 'acquir', 'chase', 'tvr', 'aid', 'tsi', 'eb00']
# Cardinal Values: ['625', '91105', '5/1/2019', '22537', '11.99', '11.99', '12', '12', '11.99', '10.25x', '1.23', '13.22', '13.22', '0.00', '051140', '912121113552', '111414448442', '13.22', '0088', '40031010', '5/1/2019', '22537']
# Products []
# Companies ['applic chase tvr 0088']
# Locations []
# Dates ['2019-05-01 00:00:00', '2040-05-11 00:00:00', '2019-05-01 00:00:00']
# MAX Value 13.22
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [1270.0, 2988.0, 2019.0, 270.0, 27.18, 3.98, 31.16, 2.57, 33.73, 33.73, 3.98, 27.18, 2019.0]
# Verbs: ['buffet']
# Nouns: ['lin', 'buffet', 'expressway', 'fet', 'kenya', 'judith', 'weekend', 'dririk', 'beverag', 'feb']
# Cardinal Values: ['01270', '2988', '2019', '8ill', '0270', '27.18', '3.98', '31.16', '2.57', '33.73', '33.73', '3.98', '27.18', '2019']
# Products []
# Companies ['beverag']
# Locations []
# Dates ['2019-01-01 00:00:00', '2019-01-01 00:00:00']
# MAX Value 33.73
#
#  ###
#
# Currency Linked Value: ['$14-36']
# Raw Values: [2361.0, 6518.0, 203.0, 909.0, 6545.0, 20048.0, 1.5, 12.0, 13.5, 0.86, 20.0, 5.64, 20200.0]
# Verbs: ['hamden']
# Nouns: ['smokeboxb', 'bbo', 'whitney', 'fxn', 'birch', 'box']
# Cardinal Values: ['2361', '06518', '203', '909', '6545', '5/22/2014', '20048', '1.50', '12.00', '13.50', '0.86', '20.00', '5.64', '5/22/2014', '20200']
# Products ['909']
# Companies ['whitney hamden 06518', 'fxn diet birch']
# Locations []
# Dates ['2014-05-22 00:00:00', '2014-05-22 00:00:00']
# MAX Value 20.0
#
#  ###
#
# Currency Linked Value: ['$20.00', '$2.18', '$3.60', '$25.78']
# Raw Values: [889.0, 90248.0, 100314.0, 375509.0]
# Verbs: ['angel', 'kae']
# Nouns: ['paradis', 'street', 'famili', 'travel', 'www.paradisedine.com', 'redit', 'purchas']
# Cardinal Values: ['889', '90248', '7/21/2018', '100314', '0375509', '20.00', '2.18', '3.60', '25.78']
# Products []
# Companies ['paradis 889', 'redit']
# Locations []
# Dates ['2018-07-21 00:00:00', '2014-10-03 00:00:00']
# MAX Value 25.78
#
#  ###
#
# Currency Linked Value: ['$9.00', '$0.00', '$12.00', '$0.00', '$0.00', '$16.00', '$3.00', '$12.00', '$4.00', '$56.00', '$3.71', '$10.08', '$69.79']
# Raw Values: [103.0, 7302.0, 2019840709.0, 2019.0]
# Verbs: ['lollipop', 'med', 'med', 'masala', 'biryani', 'lassi']
# Nouns: ['montgomerri', 'jersey', 'floor', 'chicken', 'thai', 'fri', 'rice', 'veget', 'tikka', 'veget', 'mango', '%']
# Cardinal Values: ['103', '07302', '2019840709', '24-mar-20197', '2019', '71455p', '9.00', '0.00', '12.00', '0.00', '0.00', '16.00', '3.00', '12.00', '4.00', '56.00', '3.71', '18.0', '10.08', '69.79']
# Products []
# Companies []
# Locations []
# Dates ['2019-01-01 00:00:00']
# MAX Value 69.79
#
#  ###
# Currency Linked Value: ['$12.95', '$12.95', '$1.23', '$14.18', '$14.18', '$2.33', '$16.51', '$2.59', '$16.77']
# Raw Values: [142750.0, 120.0]
# Verbs: ['pho']
# Nouns: ['tay', 'oakland', 'eleg', 'victnamesc', 'cuisinc', '@', 'tayhooakland', 'tayhooak', 'land', 'help', 'ask', 'record', 'specia', 'combo', '%']
# Cardinal Values: ['one', '142750', '2/19/19', '120', '12.95', '12.95', '1.23', '14.18', '14.18', '18.00', '2.33', '16.51', '2.59', '16.77']
# Products []
# Companies ['@tayhooakland']
# Locations []
# Dates ['2019-02-19 00:00:00']
# MAX Value 18.0
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [2540.0, 508.0, 19.0, 22.0, 114.0, 12.0, 28.5, 22.0, 6.0, 219.81, 15.38, 235.19]
# Verbs: []
# Nouns: ['falmoath', 'falmouth', 'scranton', 'ave', 'falmouth', 'abbi', 'oyster', 'chip', 'monstah', 'roll', 'chicken', 'wine', 'liquor', 'patron', 'doubl']
# Cardinal Values: ['02540', '508', '5738/1', '1..6', '19.00', '22.00', '114.00', '12.00', '28.50', '22.00', '6.00', '219.81', '15.38', '235.19']
# Products ['abbi 1']
# Companies ['monstah']
# Locations []
# Dates []
# MAX Value 235.19
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [35201.0, 94560.0, 525.0, 19.99, 39.98, 7.99, 10.0, 1.39, 7.96, 18.09, 84.02, 8.2, 92.22]
# Verbs: ['buffet', 'kid', 'kid']
# Nouns: ['newark', 'buffet', 'newark', 'blvd', 'http//www.newarkbuffet.com', 'tab', 'b11', 'qti', 'weekend', 'dinner', 'weekend', 'dinner', 'weekend', 'dinner', 'soda', 'drink', 'weekend', 'dinner', 'tax9.75', '%']
# Cardinal Values: ['35201', '94560', '0525', '06/29/2019', '19.99', '39.98', '7.99', '10.00', '1.39', '7.96', '18.09', '84.02', '8.20', '92.22']
# Products ['510-818-1136', 'tab']
# Companies []
# Locations []
# Dates ['2019-06-29 00:00:00']
# MAX Value 92.22
#
#  ###
#
# Currency Linked Value: ['$6.50', '$0.00', '$2.00', '$0.50', '$9.00', '$0.97', '$9.97']
# Raw Values: [601.0, 60804.0, 7087127173.0]
# Verbs: ['torta']
# ...
# Products ['845-1417']
# Companies ['geovanni']
# Locations []
# Dates ['2017-12-02 00:00:00']
# MAX Value 17.75
#
#  ###
#
# Currency Linked Value: ['$2.45', '$4.95', '$4.95', '$1.25', '$1.25', '$14.85', '$1.52', '$0.15', '$0.04', '$16.56', '$1240', '$2.45', '$16.56']
# Raw Values: [600.0, 64142.0, 529.0]
# Verbs: ['hater', 'taco', 'taco']
# Nouns: ['lalo', 'navi', 'claudia', 'cust', 'dquan', 'descript', 'bottl', 'pollo', 'carnita', 'chihuahua', 'chees', 'robinson', 'hill', 'count']
# Cardinal Values: ['600', '64142', '8/24/2017', '529', '2.45', '4.95', '4.95', '1.25', '1.25', '14.85', '1.52', '0.15', '0.04', '16.56', '1240', '2.45', '16.56']
# Products []
# Companies ['carnita', 'w.robinsorhillusa.con/guest-survey']
# Locations []
# Dates ['2017-08-24 00:00:00']
# MAX Value 16.56
#
#  ###
#
# Currency Linked Value: ['$41.95', '$41.95', '$10.49', '$2.94', '$55.38', '20%  $8.39 236  $965 251', '$8.39 23k', '$9.65', '$10.49']
# Raw Values: [2023.0, 34471.0, 352.0, 916.0, 415.0]
# Verbs: ['florida', 'rodizio']
# Nouns: ['panema', 'steak', 'avenu', 'ocala', 'kyle118', 'dinner', 'pay', 'thi', 'gratuity', '%', '%', '%']
# Cardinal Values: ['2023', '34471', '352', '04/13/18', '0916', '415', '41.95', '41.95', '10.49', '2.94', '55.38', '20', '20', '8.39', '236', '965', '251', '8.39', '23k', '23k', '9.65', '25', '10.49']
# Products []
# Companies []
# Locations []
# Dates ['2023-01-01 00:00:00', '2018-04-13 00:00:00']
# MAX Value 55.38
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [365.0, 35806.0, 442.0, 20111.0, 6.25, 6.25, 1.31, 7.56, 10.0, 0.44]
# Verbs: ['huntsvil']
# Nouns: ['louie', 'bridg', 'st', 'suit', 'server', 'whiskey', 'subtota', 'ask', 'host', 'parti', 'event', 'louie', 'huntsvil', 'eat', 'happi', 'huntsville', 'barlouieamerica.cor', 'close']
# Cardinal Values: ['365', '35806', '07/03/2015', '143/2', '442', '20111', '6.25', '6.25', '1.31', '7.56', '10.00']
# Products ['442']
# Companies ['bridg']
# Locations []
# Dates ['2015-07-03 00:00:00']
# MAX Value 10.0
#
#  ###
#
# Currency Linked Value: ['$41.45']
# Raw Values: [640.0, 90069.0, 1528251.0, 3430.0, 252.0, 715615506682.0, 9395.0, 554.0, 65231.0]
# Verbs: ['hollywood', 'c0347eebbf']
# Nouns: ['hedley', 'robertson', 'west', 'termin', 'ref', 'batch', 'auth', 'approv', 'c0347eebbf', 'custom', 'copi']
# Cardinal Values: ['640', '90069', '01528251', '3430', '6/5/17', '252', '715615506682', '9395', '554', '065231', '41.45', '2c362', '2c362b']
# Products []
# Companies ['uid 715615506682 ref']
# Locations []
# Dates ['2017-06-05 00:00:00']
# MAX Value 41.45
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [6910.0, 800.0, 30076.0, 5.0, 3.25, 18.95, 17.95, 45.15, 2.75, 47.9, 7.9]
# Verbs: ['ana', 'light', 'fajita', 'chicken']
# Nouns: ['charro', 'cafe', 'ventana', 'sunris', 'coor', 'ice', 'tea', 'shrimp', 'stuf', 'tanc', 'eat']
# Cardinal Values: ['6910', '06/24/2018', '24/1', '800', '30076', '5.00', '3.25', '18.95', '17.95', '45.15', '2.75', '47.90', '7.90']
# Products []
# Companies ['charro cafe ventana', 'sunris ana', 'tanc']
# Locations []
# Dates ['2018-06-24 00:00:00']
# MAX Value 47.9
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [2700.0, 78704.0, 512.0, 3008.0, 7862.0, 5.5, 2.0, 3.5, 11.0, 0.91, 11.91]
# Verbs: ['austin', 'ttl']
# Nouns: ['gourdough', 'lamar', 'jan21', 'freebird', 'ice', 'lonestar', 'origin', 'egourdoughspub']
# Cardinal Values: ['2700', '78704', '512', '3008', '7862', '0856p', '5.50', '2.00', '3.50', '11.00', '0.91', '11.91']
# Products []
# Companies ['0856p', 'lonestar', 'egourdoughspub']
# Locations []
# Dates []
# MAX Value 11.91
#
#  ###
#
# Currency Linked Value: ['$13.00', '$5.00', '$3.00', '$8.00', '$7.00', '$10.00', '$3.50', '$49.50', '$4.70', '$54.20']
# Raw Values: [2124.0, 91750.0, 909.0, 2018.0, 538.0]
# Verbs: ['burger', 'fri', 'fri', 'cheeseburg', 'burger']
# Nouns: ['fourthstreetmil', 'receip', 'bonita', 'avenu', 'subtd', 'chri', 'sep', 'lamb', 'goat', 'chees', 'medium', 'side', 'kid', 'grill', 'kid', 'potato', 'kid', 'ketchup', 'bun', 'sourdough', 'beef', 'medium', 'bacon', 'incl', '%']
# Cardinal Values: ['2124', '91750', '909', '2018', '4j33', '538', '13.00', '5.00', '3.00', '8.00', '7.00', '10.00', '3.50', '49.50', '9.5', '4.70', '54.20']
# Products ['sauc']
# Companies ['bonita', 'chees']
# Locations []
# Dates ['2124-01-01 00:00:00', '2018-01-01 00:00:00']
# MAX Value 54.2
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [14405.0, 10.95, 13.95, 10.95, 555.0, 4427.0, 4.95, 3.5, 2.79, 12.03, 11.24, 0.79, 12.03, 0.79, 555.0]
# Verbs: ['salsa', 'paid']
# Nouns: ['ppinocn', 'onion', 'salod', 'sauc', 'fop', 'grill', 'tarta', 'stufl', 'cor', 'clantrotim', 'chip', 'bull', 'cajun', 'season', 'drink', 'fri', 'rice', 'ime', 'pie', 'car', 'state', 'aug30']
# Cardinal Values: ['14405', '10.95', '13.95', '10.95', '8bo', '912341-8897', '555', '4427', '4.95', '3.50', '2.79', '12.03', '11.24', '0.79', '12.03', '0.79', '555', '14']
# Products ['fop grill choic cho 912341-8897', '0.79 ime']
# Companies ['8bo sauc']
# Locations []
# Dates []
# MAX Value 13.95
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [8620.0, 1221.0, 10020.0, 1075.0, 1061.0, 212.0, 69.5, 16.5, 10.5, 15.5, 14.5, 16.0, 25.5, 24.0, 404.0, 35.86, 439.86]
# Verbs: ['america', 'tbl', 'coke']
# Nouns: ['del', 'frisco', 'avenu', 'york', 'rebekkah', 'apr07', 'ribey', 'bone', 'cauliflow', 'bake', 'potato', 'asparagu', 'onion', 'spinach', 'voss', 'sparkl', 'totat']
# Cardinal Values: ['8620', '1221', '10020', '1075', '240/1', '1061', '16oz', '212.00', '69.50', '16.50', '10.50', '15.50', '14.50', '16.00', '25.50', '24.00', '404.00', '35.86', '439.86']
# Products ['24.00']
# Companies ["del frisco'", 'ribey', 'voss', 'coke']
# Locations []
# Dates []
# MAX Value 439.86
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [822819.0, 1344.0, 33139.0, 838.0, 40.0, 40.0, 40.0, 2.8, 0.8, 43.6, 7.2, 50.8]
# Verbs: ['florida', 'discret']
# Nouns: ['finnegan', 'way', 'drive', 'miaal', 'beach', 'tel', 'cust', 'waiter', 'iryna', 'sobe', 'mojito', 'bacardi', 'resort', 'voluntari', 'feel', 'adjust', 'remov', 'anount']
# Cardinal Values: ['822819', '1344', '33139', '08/21/17', '838', '40.00', '40.00', '40.00', '2.80', '0.80', '18x', '43.60', '7.20', '50.80']
# Products []
# Companies ['miaal beach']
# Locations []
# Dates ['2017-08-21 00:00:00']
# MAX Value 50.8
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [520.0, 188.0]
# Verbs: []
# Nouns: ['td', 'mcd', 'ocd', 'oti', 'lol', 't', 'z0d', 'l3j', 'dcd', 'ooo', 'coo']
# Cardinal Values: ['520', '188']
# Products []
# Companies []
# Locations []
# Dates []
# MAX Value 0
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [193.0, 11.5, 13.0, 17.0, 12.0, 52.0, 46.0, 13.0, 4.5, 9.0, 178.0, 15.35, 193.35, 193.35]
# Verbs: ['svrck']
# Nouns: ['parti', 'room', 'rosemari', 'caipirinha', 'crabcak', 'pepper', 'bacon', 'millenium', 'sirloin', 'brussel', 'sprout', 'espresso', 'lauren', 'hazelnut', 'tort']
# Cardinal Values: ['0193', '807p', '03/22/13', '11.50', '13.00', '17.00', '12.00', '52.00', '46.00', '13.00', '4.50', '9.00', '178.00', '15.35', '193.35', '03/22', '953ptotal', '193.35']
# Products []
# Companies ['svrck', '15.35']
# Locations []
# Dates ['2013-03-22 00:00:00']
# MAX Value 193.35
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [37011.0, 760.0, 1028.0, 50022.0, 5.9, 6.95, 8.95, 4.5, 26.3, 2.1, 28.4]
# Verbs: ['@', 'ani']
# Nouns: ['jt', 'diner', 'cook', 'street', 'braulio', 'coffe', 'egg', 'style', 'whole-wheat', 'pancak', 'sausag']
# Cardinal Values: ['37011', '760', '02/12/2016', '102/1', '1028', '50022', '2.95', '5.90', 'two', '6.95', '8.95', '4.50', '26.30', '2.10', '28.40']
# Products []
# Companies ['jt', 'coffe']
# Locations []
# Dates ['2016-02-12 00:00:00']
# MAX Value 28.4
#
#  ###
#
# Currency Linked Value: ['$22.50', '$27.00', '$49.50', '$2.97', '$52.47', '$6170', '$52.47', '$0.00']
# Raw Values: [814.0, 137.0, 87.5, 827.0]
# Verbs: ['famili']
# Nouns: ['rimo', 'darwin', 'table10', 'check1', 'prem', 'glass', 'veggi', 'darwin']
# Cardinal Values: ['5/3/19', '814', '137', '87.50', '22.50', '827.00', '27.00', '49.50', '2.97', '52.47', '6170', '52.47', '0.00']
# Products []
# Companies []
# Locations []
# Dates ['2019-05-03 00:00:00']
# MAX Value 827.0
#
#  ###
# Currency Linked Value: ['$7.99', '$8.59', '$2.99', '$13.99', '+$0.00', '+$1.99', '$10.99', '$46.54', '$3.84', '$50.38', '$50.38']
# Raw Values: [608.0, 76205.0, 185736.0, 1004.0]
# Verbs: ['bakeri', 'sarah', '+']
# Nouns: ['diner', 'denton', 'eat', 'stack', 'breakfast', 'quesadilla', 'grill', 'spinach', 'comfort', 'www.spiraldiner.com', 'acebook.com/spiraldin', 'instagram.com/spiraldin', 'busi']
# Cardinal Values: ['608', '76205', '185736', '6/16/19', '1004', '7.99', '8.59', '2.99', '13.99', '0.00', '1.99', '10.99', '46.54', '3.84', '50.38', '50.38']
# Products ['hickori denton']
# Companies ['bakeri']
# Locations []
# Dates ['2019-06-16 00:00:00']
# MAX Value 50.38
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [1130.0, 85205.0, 8.25, 2.0, 7.95, 6.75, 24.95, 2.01, 26.96]
# Verbs: ['broccoli', 'mein']
# Nouns: ['china', 'mesa', 'walk', 'boss', 'beef', 'chicken', 'fri', 'rice', 'chicken', 'chicken', 'chow', 'tax8.05', '%']
# Cardinal Values: ['1130', '85205', '8.25', '2.00', '7.95', '6.75', '24.95', '2.01', '26.96']
# Products []
# Companies []
# Locations []
# Dates []
# MAX Value 26.96
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [3035.0, 813.0, 876.0, 2587.0, 187.0, 3923.0, 0.0, 12.5, 12.8, 25.3, 1.78, 27.08]
# Verbs: ['megan']
# Nouns: ['miguel', 'kennedi', 'tampa', 'fl', "jul05'17", 'water', 'ench', 'verd', 'ench', 'manuel', 'pay', 'choos', 'miguel', 'emp']
# Cardinal Values: ['3035', '813', '876', '2587', '187', '42/1', '3923', '0.00', '12.50', '12.80', '25.30', '1.78', '27.08']
# Products []
# Companies ['megan', 'verd', 'choos miguel cafe']
# Locations []
# Dates ['2042-01-01 00:00:00']
# MAX Value 27.08
#
#  ###
#
# Currency Linked Value: ['$5.95', '$14.95', '$16.95', '$16.95', '$4.00', '$50.00', '$108.80', '$9.66', '$118.46', '$118.46']
# Raw Values: [764.0, 10019.0, 2129771010.0, 104379.0, 148.0, 35.54, 154.0]
# Verbs: ['bhajia', 'vindaloo', 'curri', 'briyani']
# Nouns: ['cotn', 'bombay', 'grill', 'indlan', 'culsin', 'bombay', 'york', 'ani', 'end', 'onion', 'lamb', 'medium', 'konkan', 'medium', 'shrimp', 'medium', 'cabernet', 'edmin', 'exand']
# Cardinal Values: ['764', '9th', '10019', '2129771010', '103638p', '104379', '5.95', '14.95', '16.95', '16.95', '4.00', '50.00', '108.80', '9.66', '118.46', '118.46', '0148', '35.54', '154.00']
# Products []
# Companies ['hous indlan culsin bombay', 'konkan']
# Locations []
# Dates []
# MAX Value 154.0
#
#  ###
#
# Currency Linked Value: ['$9.94', '$2.17', '$8.67', '$6.67', '$27.45', '$2.53', '$29.98', '$29.98', '$3.59']
# Raw Values: [26902.0, 98292.0, 40654.0, 3352.0, 10160.0]
# Verbs: ['stanwood', 'drink', 'pizza', 'mod']
# Nouns: ['mod', 'pizza', 'suit', 'aabt4hn6accm', 'draft', 'beer', 'fountain', 'mod', 'mini']
# Cardinal Values: ['26902', '92nd', '98292', '360.205.9660', '5/19/2019', '40654', '2', '04.97', '9.94', '160z', '2.17', '8.67', '6.67', '27.45', '2.53', '29.98', '29.98', '3352', '3.59', '010160']
# Products []
# Companies ['stanwood']
# Locations []
# Dates ['1992-01-01 00:00:00', '2019-05-19 00:00:00', '2060-01-01 00:00:00']
# MAX Value 29.98
#
#  ###
#
# Currency Linked Value: ["$ep30'17"]
# Raw Values: [770.0, 98188.0, 28120.0, 3885.0, 9.95, 18.95, 14.95, 33.9, 3.39, 37.29, 101.0, 10171.0, 1106.0]
# Verbs: ['anti']
# Nouns: ['ntamcmo', 'southcent', 'parokoay', 'turmila', 'janel', 'rib', 'brg', 'delukx', 'happi', 'hour', 'monday', 'happi', 'holr', 'day', 'eat', 'orink', 'club', 'a07']
# Cardinal Values: ['770', '98188', '206.575.7454', '28120', '127/1', '3885', '9.95', '1/2', '18.95', '14.95', '33.90', '3.39', '37.29', '101', '01or', '10171', '001106']
# Products []
# Companies ['ntamcmo', 'janel tbl', 'brg delukx', 'acewardsbllediain']
# Locations []
# Dates []
# MAX Value 37.29
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [134.0, 2131.0, 93449.0, 805.0, 111590.0, 1878.0, 0.0, 9.99, 19.98, 0.0, 0.0, 2.79, 17.77, 1.42, 19.19]
# Verbs: ['svo', 'club']
# Nouns: ['mario', 'callender', 'store', 'pismo', 'beach', 'www.ncpies.com', 'becki', 'tbl', 'pot', 'pie', 'pie', 'slice', 'beverag', 'drink', 'bday', 'indulge', 'home', 'whole', 'piel']
# Cardinal Values: ['0134', '2131', '93449', '805', '111590', '2/1', '1878', '0.00', '9.99', '19.98', '0.00', '0.00', '2.79', '17.77', '1.42', '19.19']
# Products []
# Companies ['svo']
# Locations []
# Dates ['2131-01-01 00:00:00', '1990-11-15 00:00:00', '1878-01-01 00:00:00']
# MAX Value 19.98
#
#  ###
#
# Currency Linked Value: ['$520']
# Raw Values: [241805.0, 74022.0, 6.8, 9.0, 18.0, 22.5, 7.5, 1.5, 65.1]
# Verbs: ['larg']
# Nouns: ['clarerdn', 'street', 'trans', 'siton', 'sostit', 'duan', 'carrig', 'lager', 'co0', 'pot', 'cake', 'portion', 'bread', 'rua', 'barruadub', 'review', 'tripadvisor', '-reprinted-']
# Cardinal Values: ['241805', '520', '17/08/2018', '074022', '6.80', '9.00', '18.00', '22.50', '7.50', '1.50', '65.10']
# Products []
# Companies ['074022', 'sostit duan carrig lager 6.80', 'tripadvisor']
# Locations []
# Dates ['2018-08-17 00:00:00']
# MAX Value 65.1
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [1805.0, 1805.0, 678.0, 102.0, 2.29, 11.99, 4.99, 19.27, 1.35, 20.62, 2.29, 8.99, 0.99, 12.27, 0.86, 13.13, 31.54, 2.21, 33.75, 33.75]
# Verbs: ['coke']
# Nouns: ['amici', 'conyer', 'parker', 'suit', 'g110', 'parker', 'nicol', 'coke', 'margherita', 'side', 'caesar', 'dbl', 'stack', 'cheeseburg', 'bacon']
# Cardinal Values: ['1805', '1805', '678', '06/10/2018', '52/1', '102', '2.29', '11.99', '4.99', '19.27', '1.35', '20.62', '2.29', '8.99', '0.99', '12.27', '0.86', '13.13', '31.54', '2.21', '33.75', '33.75']
# Products ['2.29 dbl']
# Companies ['amici conyer 1805 parker', 'caesar', 'coke']
# Locations []
# Dates ['1805-01-01 00:00:00', '1805-01-01 00:00:00', '2018-06-10 00:00:00', '2052-01-01 00:00:00']
# MAX Value 33.75
#
#  ###
#
# Currency Linked Value: ['$20.00', '$18.00', '$17.00', '$55.00', '$3.30', '$58.30']
# Raw Values: [71128.0, 60602.0]
# Verbs: ['tikka']
# Nouns: ['*', 'tai', 'happi', 'count', 'murgh', 'palak', 'paneer', 'chees']
# Cardinal Values: ['71128', '12/31/2018', '60602', '20.00', '18.00', '17.00', '55.00', '3.30', '58.30']
# Products []
# Companies ['chees']
# Locations []
# Dates ['2018-12-31 00:00:00']
# MAX Value 58.3
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [200430635.0, 0.5, 1.0, 5.0, 10.0, 10.0, 8.0, 4.0, 1.0, 3400.0, 1.0, 1241.0, 45400311.0]
# Verbs: ['stovigli']
# Nouns: ['stabil', 'imento', 'marino', 'montano', 'montano', 'lacco', 'ameno', 'partita', 'macedonia', 'insalata', 'bufala', 'pomodorin', 'contant', 'reg', 'scontrino']
# Cardinal Values: ['00200430635', '0.50', '1.00', '5.00', '10.00', '10.00', '8.00', '4.00', '1/2', '1.00', '3400', '001', '1241', '45400311']
# Products []
# Companies ['oper']
# Locations []
# Dates []
# MAX Value 10.0
#
#  ###
#
# Currency Linked Value: ['$154.78', '$25.56', '$28.40', '$31.24']
# Raw Values: [33140.0, 100.0, 1959.0, 16.0, 0.0, 16.0, 62.0, 13.0, 12.0, 13.0, 10.0, 142.0, 7.7, 2.24, 2.84, 209.0]
# Verbs: ['frle', 'gratuiti']
# Nouns: ['stk', 'mlami', 'beach', 'collin', 'm1anl', 'avion', 'silver', 'staut', 'avion', 'silver', 'margarita', 'delmonico', 'truffl', 'mac/chees', 'bake', 'cooki', 'bev', 'resort', 'conveni']
# Cardinal Values: ['33140', '100', '103/1', '1959', '25aug17', '16.00', '0.00', '16.00', '62.00', '13.00', '12.00', '13.00', '10.00', '142.00', '7.70', '2.24', '2.84', '154.78', '18x', '25.56', '209', '28.40', '22x', '31.24']
# Products ['25aug17', 'eargarita staut 0.00 avion']
# Companies ['stk mlami beach', 'truffl', 'mac', 'cooki', 'bev']
# Locations []
# Dates ['1959-01-01 00:00:00', '2017-08-25 00:00:00']
# MAX Value 154.78
#
#  ###
#
# Currency Linked Value: []
# Raw Values: [9255.0, 90069.0, 933.0, 17.0, 20.0, 28.0, 14.0, 12.0, 12.0, 13.0, 2.0, 118.0, 118.0, 10.33, 128.33]
# Verbs: ['tonno']
# Nouns: ['b1vd', 'hol', 'lyuood', 'tel', 'sarah', 'tartar', 'linuin', 'scampi', 'branzino', 'p127a', 'americana', 'carrot', 'cake', 'sangioves', 'merlot', 'misc']
# Cardinal Values: ['9255', '90069', '05/21/12', '933', '17.00', '20.00', '28.00', '14.00', '12.00', '12.00', '13.00', '2.00', '118.00', '118.00', '10.33', '128.33']
# Products []
# Companies ['noe 9255', 'west sunoet', 'linuin scampi']
# Locations []
# Dates ['2012-05-21 00:00:00']
# MAX Value 128.33
#
#  ###
#
# Text Enrichment Finished. 200 Records processed, 2887 Tokens removed

# %% [markdown]
# ### 2.2 Basic Analysis of Enriched Results

# %%
def analyse_records(records_enriched, word_cloud=False):
    

    words_conf = []
    dates = []
    values = []
    #raw data
    for key,data in records_enriched.items():
        
#         print(data['max_value'])
        words_conf = words_conf + data['word_confidences']
        dates = dates + data['dates']
        values.append(data['max_value'])
        
    #let's look at the distribution of confidence scores.    
    df_words = pd.DataFrame(words_conf)
    df_max_values = pd.DataFrame({'max_values':values})
    print('Total Non-unique Tokens {}'.format(df_words.shape[0]))
    
    print('Unique Tokens {}'.format(df_words['word'].unique().shape[0]))
    n = 10
    top_n_terms = df_words['word'].value_counts()[:n].index.tolist()
    print('Top {} Common Tokens {}'.format(n, top_n_terms))
    print('Highest Total Value {} '.format(max(df_max_values['max_values'])))
    print('Lowest Total Value {} '.format(min(df_max_values['max_values'])))
    print('Mean Total Value {} '.format(round(df_max_values['max_values'].mean(),2)))

    df_words.hist()
    df_max_values.plot.hist(bins=100)

    words_list_non_unique = df_words['word'].tolist()
    
    
    #Simple word cloud to view our data.
    if word_cloud:
        string_of_words = ' '.join(map(str, words_list_non_unique)) 
        wordcloud = WordCloud(
            width = 3000,
            height = 2000,
            background_color = 'black',
            stopwords = STOPWORDS).generate(string_of_words)
        fig = plt.figure(
        figsize = (40, 30),
        facecolor = 'k',
        edgecolor = 'k')
        plt.imshow(wordcloud, interpolation = 'bilinear')
        plt.axis('off')
        plt.tight_layout(pad=0)
        plt.show()

#         df_dates = pd.DataFrame(dates)
#         df_dates.plot()

    return df_words
df_words = analyse_records(records_enriched, word_cloud=False)
# Out:
# Total Non-unique Tokens 7851
# Unique Tokens 4832
# Top 10 Common Tokens ['0.00', 'fri', 'chicken', '$0.00', '12.00', 'taco', 'coke', 'chees', 'grill', 'shrimp']
# Highest Total Value 827.0
# Lowest Total Value 0.0
# Mean Total Value 67.59

# %% [markdown]
# ### 2.3 Token Co-Occurrence
#
# It might be quite nice to understand the co-occurance of items within receipts.
#
# For those who have worked in this space before, we can used SVD techniques to calculate the co-occurance, or libraries such as GloVe, which uses Vector Spaces of word representations in order to analyse the tokens.
#
# For this example, we're going to start off with a very simple counter based approach

# %%
def token_coocurance(records_enriched, combination_size = 2):
    
    cooc_counts = {}
    for key,data in records_enriched.items():
        
        tokens = data['tokens']
        cleaned = [ x for x in tokens if (not x.isdigit()) and (len(x)> 2) ]
       
        #remove dups
        cleaned =  list(dict.fromkeys(cleaned))
        cooc = list(combinations(cleaned, combination_size)) 
        
        for occ in cooc:
            if occ in cooc_counts:
                cnt = cooc_counts[occ]
                cooc_counts[occ] = cnt +1
            else:
                cooc_counts[occ] = 1
    
    print('Total Unique Token Co-Occurrences {}'.format(len(cooc_counts)))
    cooc_counts_sorted = dict( sorted(cooc_counts.items(), key=operator.itemgetter(1),reverse=True))
    top_k = 50
    cnt = 0
    
   
         
    min_cooc_cnt = 3   
    cooc_counts_sorted_filtered = {key:val for key, val in cooc_counts_sorted.items() if val > min_cooc_cnt}

    for k,v in cooc_counts_sorted_filtered.items():
        if cnt < top_k:
            print(k, v)
            cnt+= 1
            
    print('Filtered (min count {}) Unique Token Co-Occurrences {}'.format(min_cooc_cnt, len(cooc_counts_sorted_filtered)))
        

token_coocurance(records_enriched, combination_size = 2)
# Out:
# Total Unique Token Co-Occurrences 99692
# ('parti', 'svrck') 7
# ('12.00', '10.00') 7
# ('12.00', '6.00') 7
# ('chees', 'fri') 6
# ('fri', 'rice') 6
# ('ice', 'tea') 6
# ('chees', '0.00') 5
# ('chicken', '12.00') 5
# ('french', 'fri') 5
# ('chicken', 'rice') 5
# ('12.00', '13.00') 5
# ('new', 'york') 5
# ('drive', 'thru') 4
# ('settl', 'tender') 4
# ('tender', '0.00') 4
# ('5.00', '10.00') 4
# ('12.00', '11.00') 4
# ('diet', 'coke') 4
# ('8.00', '4.00') 4
# ('3.00', '7.00') 4
# ('beach', 'sub-tot') 4
# ('tel', 'sub-tot') 4
# ('cust', 'sub-tot') 4
# ('grill', 'fri') 4
# ('avenu', 'side') 4
# ('fri', '2.50') 4
# ('acct', 'auth') 4
# ('fri', '3.50') 4
# ('8.00', '10.00') 4
# ('sub-tot', '0.00') 4
# ('famili', '0.00') 4
# ('med', '0.00') 4
# ('beach', '0.00') 4
# ('mexican', 'chicken') 4
# ('shrimp', '0.00') 4
# ('chicken', '0.00') 4
# ('custom', 'copi') 4
# ('ave', 'chicken') 4
# ('18.00', '6.00') 4
# ('17.00', '12.00') 4
# ('0.00', 'fri') 4
# ('sauc', 'fri') 4
# ('0.00', '3.99') 4
# ('0.00', 'bake') 4
# ('chicken', 'beef') 4
# ('tbl', '0.00') 4
# Filtered (min count 3) Unique Token Co-Occurrences 46

# %% [markdown]
# ### 2.4 Word Embeddings
#
# Another approach is to examine the word embeddings of the text in order to determine relationships between the terms (tokens) within the data.
#
# Word2Vec is a popular algorithm used for generating dense vector representations of words in large corpora using unsupervised learning. The resulting vectors have been shown to capture semantic relationships between the corresponding words and are used extensively for many downstream natural language processing (NLP) tasks like sentiment analysis, named entity recognition and machine translation.
#
# In order to acheive this, we're going to be using SageMaker's ```blazingtext``` estimator.

# %%
def prep_data_form_sagemaker_training(configs, global_vars, records_enriched):
    
    tokens = []
    #raw data
    for key,data in records_enriched.items():
        
#         print(data['max_value'])
        tokens = tokens + data['tokens']
    
    cleaned = [ x for x in tokens if (not x.isdigit()) and (len(x)> 2) ]

    corpus = ' '.join(map(str, cleaned)) 
    print('Total Corpus Size: {} Tokens'.format(len(tokens)))
    print('Total Char Size: {} '.format(len(corpus)))
    
    return corpus
    
    
corpus = prep_data_form_sagemaker_training(configs, global_vars, records_enriched)
# Out:
# Total Corpus Size: 8956 Tokens
# Total Char Size: 44707

# %%
def upload_corpus_to_s3(configs, global_vars, corpus):
    
         
    dataset_key = 'train'
    s3_bucket = global_vars['s3_bucket']
    
    sess = global_vars['sess']
    bucket = global_vars['s3_bucket']
    
    with open(dataset_key, 'w') as f:
        f.write(corpus)
   
        
    data_file_s3 = configs['training_data_prefix_s3'] + dataset_key
    s3_bucket.upload_file(dataset_key, data_file_s3)   

    s3_train_data = 's3://{}/{}'.format(configs['bucket_name'], configs['training_data_prefix_s3'])
    s3_output_location = 's3://{}/output'.format(configs['bucket_name'])
    configs['s3_train_data'] = s3_train_data
    configs['s3_output_location'] = s3_output_location

    print('S3 Training Data Path {}'.format(s3_train_data))
    print('S3 Training Data Path {}'.format(s3_output_location))

    return configs
configs = upload_corpus_to_s3(configs, global_vars, corpus)
# Out:
# S3 Training Data Path s3://aws-demo-receipts/training_data/
# S3 Training Data Path s3://aws-demo-receipts/output

# %%
def configure_estimator(configs, global_vars):
    
    region_name = configs['aws_region'] 
    sess = global_vars['sess']
    container = sagemaker.amazon.amazon_estimator.get_image_uri(region_name, "blazingtext", "latest")
    print('Using SageMaker BlazingText container: {} ({})'.format(container, region_name))

    bt_model = sagemaker.estimator.Estimator(container,
                                         global_vars['role'], 
                                         train_instance_count=2, 
                                         train_instance_type='ml.c4.2xlarge',
                                         train_volume_size = 5,
                                         train_max_run = 360000,
                                         input_mode= 'File',
                                         output_path=configs['s3_output_location'],
                                         sagemaker_session=sess)
    
    bt_model.set_hyperparameters(mode="batch_skipgram",
                             epochs=5,
                             min_count=5,
                             sampling_threshold=0.0001,
                             learning_rate=0.05,
                             window_size=5,
                             vector_dim=100,
                             negative_samples=5,
                             batch_size=11, #  = (2*window_size + 1) (Preferred. Used only if mode is batch_skipgram)
                             evaluation=True,# Perform similarity evaluation on WS-353 dataset at the end of training
                             subwords=False) # Subword embedding learning is not supported by batch_skipgram
    
    train_data = sagemaker.session.s3_input(configs['s3_train_data'], distribution='FullyReplicated', 
                        content_type='text/plain', s3_data_type='S3Prefix')

    data_channels = {'train': train_data}
    
   
    global_vars['train_data'] = train_data
    global_vars['data_channels'] = data_channels
    global_vars['bt_model'] = bt_model
    
    return global_vars

global_vars = configure_estimator(configs, global_vars)
# Out:
# Using SageMaker BlazingText container: 811284229777.dkr.ecr.us-east-1.amazonaws.com/blazingtext:latest (us-east-1)

# %%
def fit_model(configs, global_vars):
    
    bt_model = global_vars['bt_model']
    data_channels = global_vars['data_channels']
    bt_model.fit(inputs=data_channels, logs=True)
    
    
fit_model(configs, global_vars)
# Out:
# 2020-03-18 08:36:38 Starting - Starting the training job...
# 2020-03-18 08:36:42 Starting - Launching requested ML instances......
# 2020-03-18 08:37:45 Starting - Preparing the instances for training...
# 2020-03-18 08:38:37 Downloading - Downloading input data......
# 2020-03-18 08:39:23 Training - Training image download completed. Training in progress.Arguments: train
# Arguments: train
# Found 10.2.182.94 for host algo-1
# Found 10.2.129.203 for host algo-2
# Found 10.2.182.94 for host algo-1
# Found 10.2.129.203 for host algo-2
# [03/18/2020 08:39:37 WARNING 140172897224512] Loggers have already been setup.
# [03/18/2020 08:39:37 WARNING 140172897224512] Loggers have already been setup.
# [03/18/2020 08:39:37 INFO 140172897224512] nvidia-smi took: 0.0251920223236 secs to identify 0 gpus
# [03/18/2020 08:39:37 INFO 140172897224512] Running distributed CPU BlazingText training using batch_skipgram on 2 hosts.
# [03/18/2020 08:39:37 INFO 140172897224512] Number of hosts: 2, master IP address: 10.2.182.94, host IP address: 10.2.129.203.
# [03/18/2020 08:39:38 WARNING 140091626751808] Loggers have already been setup.
# [03/18/2020 08:39:38 WARNING 140091626751808] Loggers have already been setup.
# [03/18/2020 08:39:38 INFO 140091626751808] nvidia-smi took: 0.0252230167389 secs to identify 0 gpus
# [03/18/2020 08:39:38 INFO 140091626751808] Running distributed CPU BlazingText training using batch_skipgram on 2 hosts.
# [03/18/2020 08:39:38 INFO 140091626751808] Number of hosts: 2, master IP address: 10.2.182.94, host IP address: 10.2.182.94.
# [03/18/2020 08:39:38 INFO 140091626751808] HTTP server started....
# [03/18/2020 08:39:38 INFO 140091626751808] Processing /opt/ml/input/data/train/train . File size: 0 MB
# Warning: Permanently added 'algo-2,10.2.129.203' (ECDSA) to the list of known hosts.#015
# processor name: algo-1, number of processors: 2, rank: 0
# processor name: algo-2, number of processors: 2, rank: 1
# Read 0M words
# Number of words:  234
# Alpha: 0.0500  Progress: 154.22%  Million Words/sec: 0.53
# Alpha: 0.0500  Progress: 211.98%  Million Words/sec: 0.36
# Alpha: 0.0500  Progress: 100.00%  Million Words/sec: 0.17
#
# Training finished!
# Average throughput in Million words/sec: 0.17
# Total training time in seconds: 0.20
# Evaluating word embeddings....
# Vectors read from: /opt/ml/model/vectors.txt
# {
#     "EN-WS-353-ALL.txt": {
#         "not_found": 351,
#         "spearmans_rho": 1.0,
#         "total_pairs": 353
#     },
#     "EN-WS-353-REL.txt": {
#         "not_found": 252,
#         "spearmans_rho": 0.0,
#         "total_pairs": 252
#     },
#     "EN-WS-353-SIM.txt": {
#         "not_found": 201,
#         "spearmans_rho": 1.0,
#         "total_pairs": 203
#     },
#     "mean_rho": 0.6666666666666666
# }
# [03/18/2020 08:39:43 INFO 140091626751808] #mean_rho: 0.6666666666666666

# %%
def host_endpoint(configs, global_vars):
        
    bt_model = global_vars['bt_model']

    bt_endpoint = bt_model.deploy(initial_instance_count = 1,instance_type = 'ml.m4.xlarge')

    global_vars['bt_endpoint']  = bt_endpoint 
    return global_vars
    
# global_vars = host_endpoint(configs, global_vars)

# %%
def download_model_results(configs, global_vars):
    
    bt_model = global_vars['bt_model']
    s3 = global_vars['s3']
    bucket_name = configs['bucket_name']
    model_filename = 'model.tar.gz'
    key = bt_model.model_data[bt_model.model_data.find("/", 5)+1:]
    s3.Bucket(bucket_name).download_file(key, model_filename )

    #untar file
    tar = tarfile.open(model_filename)
    tar.extractall()
    tar.close()

download_model_results(configs, global_vars)

# %%
def evaluate_model_results():
    num_points = 150

    first_line = True
    index_to_word = []
    cnt  = 0
    with open("vectors.txt","r") as f:
        for line_num, line in enumerate(f):
            if first_line:
                dim = int(line.strip().split()[1])
                word_vecs = np.zeros((num_points, dim), dtype=float)
                first_line = False
                continue
            line = line.strip()
            word = line.split()[0]
            vec = word_vecs[line_num-1]
            for index, vec_val in enumerate(line.split()[1:]):
                vec[index] = float(vec_val)
            index_to_word.append(word)
            if line_num >= num_points:
                break
            cnt +=1
    word_vecs = normalize(word_vecs, copy=False, return_norm=False)
    print('Total Vector Space {}'.format(cnt))

    tsne = TSNE(perplexity=10, n_components=2, init='pca', n_iter=10000, verbose=1)
    two_d_embeddings = tsne.fit_transform(word_vecs[:num_points])
    labels = index_to_word[:num_points]
    
    print('Total Tokens {}'.format(len(labels)))
    
    return two_d_embeddings, labels

two_d_embeddings, labels = evaluate_model_results()
# Out:
# Total Vector Space 149
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 150 samples in 0.000s...
# [t-SNE] Computed neighbors for 150 samples in 0.007s...
# [t-SNE] Computed conditional probabilities for sample 150 / 150
# [t-SNE] Mean sigma: 0.253739
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.670410
# [t-SNE] KL divergence after 3450 iterations: 1.476407
# Total Tokens 150

# %% [markdown]
# #### Plotting Embeddings
#  t-SNE and Word2Vec are stochastic, so although when you run the code the plot won’t look the same everytime the methods are executed

# %%
def plot(embeddings, labels):
    pylab.figure(figsize=(20,20))
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

plot(two_d_embeddings, labels)

# %% [markdown]
# Notes: Compared to the Word Co-Occurence Approach, work embeddings usign Skip-Grams provide an abstraction of tokens within a given vector space, which allows for relationships between different words to be exposed! We can see from the results, we are seeing words such as Pasta, Pizza, and Cheese occuring within the same vector space, for instance. Pretty good considering the tokens used to build our embeddings was extremely small!
